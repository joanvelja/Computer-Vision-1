# %% [markdown]
# <center><img src="https://editor.analyticsvidhya.com/uploads/46151Deep_Learning_Software_DE_1380x735px_1150x_.png" width=50% ></center>
#
# # <center> Lab Project Part 2: Image Classification using Convolutional Neural Networks </center>
# <center> Computer Vision 1, University of Amsterdam </center>
# <center> Due 23:59, October 21, 2023 (Amsterdam time) </center>
#
# ***
#
# <center>
# <b>TA's: Xiaoyan Xing, Vladimir Yugay, Luca Pantea</b>
#
# Student1 ID: \
# Student1 Name:
#
# Student2 ID: \
# Student2 Name:
#
# Student3 ID: \
# Student3 Name:
#
# ( Student4 ID: \
# Student4 Name: )
# </center>

# %% [markdown]
# # **Instructions**
#
# 1. Students are expected to prepare a report covering both sections of this assignment. The report should include answers to all questions, written details on implementation approaches, the analysis of the results for different settings and visualizations to illustrate experiments with and performance of your implementation. Grading will primarily be based on the report (i.e. it should be self-contained as much as possible). If the report contains any faulty results or ambiguities, the TA's can take a look at your code to find out what happened.
#
# 2. Do not just provide numbers without explanation, remember to follow the general guidelines and discuss different settings to show you understand the material and the processes at work.
#
# 3. This part of the Final Lab contains an *optional* bonus challenge. See section 3 below.
#
# **Hint:** Having visual elements such as charts, graphs and plots are always useful for everyone. Keep this in mind while writing your reports.

# %% [markdown]
# # **General Guidelines**
# 1. **Aim**:
#      - Able to understand Image Recognition/Classification using Convolutional Neural Networks.
#      - Get familiar with PyTorch, widely used Deep Learning framework
# 2. **Prerequisites**:
#      - Familiarity with Python and relevant packages.
#      - Know the basics of feature descriptors (SIFT, HoG) and machine learning tools (K-means, SVM and etc.).
# 3. **Guidelines**:
#     Students should work on the assignments in their assignment group for **two** weeks.
#
#     Any questions regarding the assignment content can be discussed on Piazza.
#
#     Your source code and report must be handed in together in a zip file (**ID1_ID2_ID3_part2.zip**) before the deadline. Make sure your report follows these guidelines:
#     - *The maximum number of pages for this part is 10 (single-column, including tables and figures). Please express your thoughts concisely.*
#     - *Follow the given instructions and answer all given questions. **Briefly describe what you implemented for each question in the report**.*
#     - *Show you understand the algorithms and implementations: explain why certain settings produce certain results. When constructing graphs, tables and other figures, make your figures as informative as possible (choose relevant sample sizes, axes, etc.), to illustrate your arguments*
#     - *Tables and figures must be accompanied by a brief description. Do not forget to add a number, a title, and if applicable name and unit of variables in a table, name and unit of axes and legends in a figure.*
#
# 4. The report should be handed in in **PDF-format**. Your code should be handed in in **.ipynb format** (Jupyter Notebook). This does not mean you have to make your project in a notebook, it just means it **should be submitted as a notebook**. This means that you can, for example, have separate python files in which you declare your classes/methods, but **_you will have to initialize/call these in the final notebook before you submit_**. Be sure to test whether all your functionality works as expected when ran in a notebook (**Before submission, go in the `Kernel` tab and press `Restart & Run All`**). If you use a Conda environment, be sure to include it in your submission.
#
# 5. **Late submissions** are not allowed. Assignments that are submitted after the strict deadline will not be graded. In case of submission conflicts, TAs' system clock is taken as reference. We strongly recommend submitting well in advance, to avoid last minute system failure issues.
#
# 6. **Plagiarism note**: Keep in mind that plagiarism (submitted materials which are not your work) is a serious crime and any misconduct shall be punished with the university regulations. This includes the use of ChatGPT and other generative AI tools.
#
# <!-- ### PyTorch versions
# we assume that you are using latest PyTorch version(>=1.4)
#
# ### PyTorch Tutorial & Docs
# This tutorial aims to make you familiar with the programming environment that will be used throughout the course. If you have experience with PyTorch or other frameworks (TensorFlow, MXNet *etc.*), you can skip the tutorial exercises; otherwise, we suggest that you complete them all, as they are helpful for getting hands-on experience.
#
# **Anaconda Environment** We recommend installing \textit{anaconda} for configuring \textit{python} package dependencies, whereas it's also fine to use other environment managers as you like. The installation of anaconda can be found in [anaconda link](https://docs.anaconda.com/anaconda/install/).
#
# **Installation** The installation of PyTorch is available at [install link](https://pytorch.org/get-started/locally/) depending on your device and system.
#
# **Getting start** The 60-minute blitz can be found at [blitz](https://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html), and and examples are at [examples](https://pytorch.org/tutorials/beginner/pytorch_with_examples.html)
#
# **Documents** There might be potential unknown functions or classes, you shall look through the official documents website ([Docs](https://pytorch.org/docs/stable/index.html)) and figure them out by yourself. (***Think***:} What's the difference between *torch.nn.Conv2d* and *torch.nn.functional.conv2d*?)
# You can learn pytorch from the [tutorial link](https://pytorch.org/tutorials/). The Docs information can be searched at [Docs](https://pytorch.org/docs/stable/index.html). In this assignments, we wish you to form the basic capability of using one of the well-known   -->

# %% [markdown]
# #  **Introduction**
#
# This part of the assignment makes use of Convolutional Neural Networks (CNN's). The previous part makes use of hand-crafted features like SIFT to represent images, then trains a classifier on top of them. In this way, learning is a two-step procedure with image representation and learning. The method used here instead *learns* the features jointly with the classification. Training CNNs roughly consists of three parts:
# 1. Creating the network architecture
#
# 2. Preprocessing the data
#
# 3. Feeding the data to the network, and updating the parameters.
#
# Please follow the instructions and finish the below tasks. (**Note:**  you are allowed to change the provided code.)

# %% [markdown]
# # **Section 1: Image Classifiation on CIFAR-100**
# ### 1.1 Install pytorch and run the given code
#
# First of all, you need to install PyTorch and relevant packages. In this part, we will use [CIFAR-100](https://www.cs.toronto.edu/~kriz/cifar.html) as the training and testing dataset.

# %%
#####################################################
# referenced code: https://pytorch.org/tutorials/
# referenced code: http://cs231n.stanford.edu/
# referenced code: https://cs.stanford.edu/~acoates/stl10/
######################################################
import torch
import torchvision
import torchvision.transforms.v2 as transforms
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
import numpy as np
import torch.optim as optim
import wandb
from PIL import Image

from torch.utils.data import DataLoader, random_split, Dataset

torch.device("mps")
# Out:
# device(type='mps')

# %%
# !wandb login
# Out:
# wandb: Currently logged in as: joanvelja (1000kelvin). Use `wandb login --relogin` to force relogin

# %%
#transform = transforms.Compose(
#    [transforms.ToTensor(),
#     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

transform = transforms.Compose(
    [transforms.ToImage(),
    transforms.ToDtype(torch.float32, scale=True),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=5,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR100(root='./data', train=False,
                                       download=False, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4,
                                         shuffle=False, num_workers=2)

classes = ('apple', 'aquarium_fish', 'baby','bear', 'beaver','bed','bee','beetle','bicycle','bottle', 'bowl','boy','bridge', 'bus','butterfly', 'camel','can','castle','caterpillar','cattle',
 'chair','chimpanzee','clock','cloud', 'cockroach','couch', 'cra','crocodile', 'cup','dinosaur','dolphin', 'elephant','flatfish', 'forest', 'fox','girl', 'hamster', 'house','kangaroo','keyboard',
'lamp', 'lawn_mower', 'leopard', 'lion','lizard','lobster', 'man','maple_tree','motorcycle', 'mountain', 'mouse','mushroom','oak_tree', 'orange','orchid', 'otter', 'palm_tree','pear', 'pickup_truck','pine_tree',
'plain', 'plate', 'poppy','porcupine','possum','rabbit','raccoon','ray','road','rocket','rose','sea', 'seal', 'shark','shrew', 'skunk','skyscraper', 'snail','snake','spider',
'squirrel', 'streetcar', 'sunflower','sweet_pepper', 'table','tank','telephone', 'television', 'tiger','tractor','train','trout', 'tulip', 'turtle','wardrobe', 'whale', 'willow_tree','wolf', 'woman','worm')
# Out:
# Files already downloaded and verified

# %% [markdown]
# ####  **` Q1.1: Test dataloader and show the images of each class  of CIFAR-100 (3-pts)`**
# You need to run and modify the given code and **show** the example images of CIFAR-100, **describe** the classes and images of CIFAR-100. (Please visualize at least one picture for the classes of labels from 0 to 4.) (3-*pts*)

# %%
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %%
# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)

# show images
imshow(torchvision.utils.make_grid(images))

# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(5)))
# Out:
# telephone lizard  worm cockroach otter

# %% [markdown]
# ### 1.2 Architecture understanding
#
# In this section, we provide templates for two classes inheriting from the PyTorch superclass [*nn.Module*](https://pytorch.org/docs/stable/generated/torch.nn.Module.html) (the base class for all neural network modules). One is an ordinary two-layer network (*TwolayerNet*) with fully connected layers and ReLu, and the other is a Convolutional Network (*ConvNet*) utilizing the structure of [LeNet-5](https://ieeexplore.ieee.org/document/726791).
#
# **Note**: you are allowed to change the provided function definitions.

# %% [markdown]
# ####  **`Q1.2: Architecture understanding. Implement architecture of TwolayerNet and ConvNet (4-pts).`**
#
# 1. Complement the architecture of *TwolayerNet* class, and complement the architecture of *ConvNet* class using the structure of LeNet-5. (2-*pts*)
# 2. Since you need to feed color images into these two networks, what's the kernel size of the first convolutional layer in *ConvNet*? and how many trainable parameters are there in "F6" layer (given the calculation process)? (2-*pts*)

# %%
class TwoLayerNet(nn.Module):
    '''
    This is a two layer network with ReLU nonlinearity. The structure is linear->ReLU->linear.
    '''
    # assign layer objects to class attributes
    # nn.init package contains convenient initialization methods
    # http://pytorch.org/docs/master/nn.html#torch-nn-init
    def __init__(self, input_size, hidden_size, num_classes = 100):
        '''
        Args:
            input_size: 3*32*32 for CIFAR100
            hidden_size : Number of neurons in the hidden layer 
            num_classes: Number of classes of the classification problem. Default 100 for CIFAR100
        '''
        super(TwoLayerNet, self).__init__()
        
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, num_classes)

    def forward(self,x):
        x = x.view(x.shape[0], -1)
        scores = self.fc2(F.relu(self.fc1(x)))
        return scores

# %%
class ConvNet(nn.Module):
    '''
    Convolutional Neural Network based on LeNet-5 architecture.
    The network consists of the following layers:
        - After each convolutional layer, a tanh non-linearity is applied.
        - After each subsampling layer, an average pooling operation is applied.
        - After the last convolutional layer, two fully connected layers are applied with tanh non-linearity.
    '''
    def __init__(self, num_classes=100):
        '''
        Args:
            num_classes: Number of classes of the classification problem. Default 100 for CIFAR100
        '''
        super(ConvNet, self).__init__()
        # First Convolutional Layer with 6 filters
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5, stride=1)
        self.act1 = nn.Tanh()
        self.pool1 = nn.AvgPool2d(kernel_size=2, stride=2)

        # Second Convolutional Layer with 16 filters
        self.conv2 = nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, stride=1)
        self.act2 = nn.Tanh()
        self.pool2 = nn.AvgPool2d(kernel_size=2, stride=2)

        # Fully Connected Layers
        self.fc1 = nn.Linear(in_features=16*5*5, out_features=120) # 5*5 from image dimension
        self.act3 = nn.Tanh()
        self.fc2 = nn.Linear(in_features=120, out_features=84)
        self.act4 = nn.Tanh()
        self.fc3 = nn.Linear(in_features=84, out_features=num_classes)

    def forward(self, x):
        x = x.permute(0, 3, 1, 2)  # Rearrange dimensions to [batch_size, channels, height, width]
        x = self.pool1(self.act1(self.conv1(x)))
        x = self.pool2(self.act2(self.conv2(x)))
        x = x.view(-1, 16*5*5)
        x = self.act3(self.fc1(x))
        x = self.act4(self.fc2(x))
        x = self.fc3(x)
        return x

# %% [markdown]
# ### 1.3 Preparation of training
#
# In above section, we use the *CIFAR-100* dataset class from *torchvision.utils* provided by PyTorch. Whereas in most cases, you need to prepare the dataset yourself. One of the ways is to create a *dataset* class yourself and then use the *DataLoader* to make it iterable. After preparing the training and testing data, you also need to define the transform function for data augmentation and optimizer for parameter updating.

# %% [markdown]
# ####  **` Q1.3: Preparation of training. Create the Dataloader class, define the transform function and the optimizer.(8-pts)`**
# 1. Complement the *CIFAR100\_loader* (2-pts)
# 2. Complement the *Transform* function and the *Optimizer* (2-pts)
# 3. Train the *TwolayerNet* and *ConvNet* with *CIFAR100\_loader*, *Transform* and *Optimizer* you implemented and compare the results (4-pts)

# %% [markdown]
# ##### *` Complement the CIFAR100_loader class (2-pts)`*

# %%
###  suggested reference: https://pytorch.org/tutorials/
# recipes/recipes/custom_dataset_transforms_loader.html?highlight=dataloader
# functions to show an image

class CIFAR100_loader(torch.utils.data.Dataset):
    def __init__(self, root, train=True, transform=None):
        '''
        CIFAR-100 dataset loader
        
        Args:
            root (string): Root directory of dataset where directory
                ``cifar-100-python`` exists or will be saved to if download is set to True.
            train (bool, optional): If True, creates dataset from training set, otherwise
                creates from test set.
            transform (callable, optional): A function/transform that  takes in an PIL image
                and returns a transformed version. E.g, ``transforms.RandomCrop``
        '''

        self.root = root
        self.train = train
        self.transform = transform
        self.data = torchvision.datasets.CIFAR100('data', train=train, download=True, transform=transform)
        self.images = self.data.data
        self.labels = self.data.targets
        

    def __len__(self):
        return len(self.data)

    def __getitem__(self, item):
        
        if torch.is_tensor(item):
            item = item.tolist()

        image = self.images[item]
        label = self.labels[item]
                
        return image, label

# %% [markdown]
# ##### *` Complement the Transform function and the Optimizer (2-pts)`*

# %%
transform_train = transform
transform_test = transform

optimizer = optim.SGD

# %% [markdown]
# ##### *` Train the TwolayerNet and ConvNet with CIFAR100_loader, transform and optimizer you implemented and compare the results (4-pts)`*

# %%
def valid(net, testloader):
    net.eval()
    device = torch.device('cuda') if torch.cuda.is_available() else (torch.device('mps') if torch.backends.mps.is_available() else torch.device('cpu'))
    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            inputs, labels = data
            inputs, labels = inputs.to(device).float(), labels.to(device)
            outputs = net(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    print('Accuracy of the network on the 10000 test images: %d %%' % (accuracy))
    return accuracy

# %%
def valid_class(net, testloader, classes):
    net.eval()
    device = torch.device('cuda') if torch.cuda.is_available() else (torch.device('mps') if torch.backends.mps.is_available() else torch.device('cpu'))
    class_correct = list(0. for _ in range(len(classes)))
    class_total = list(0. for _ in range(len(classes)))
    with torch.no_grad():
        for data in testloader:
            inputs, labels = data
            inputs, labels = inputs.to(device).float(), labels.to(device)
            outputs = net(inputs)
            _, predicted = torch.max(outputs, 1)
            c = (predicted == labels).squeeze()
            for i in range(len(labels)):
                label = labels[i]
                class_correct[label] += c[i].item()
                class_total[label] += 1

    for i in range(len(classes)):
        print('Accuracy of %5s : %2d %%' % (
            classes[i], 100 * class_correct[i] / class_total[i]))

    return class_correct, class_total

# %%
def compare_classifiers(net1, net2, testloader, classes):
    class_correct1, class_total1 = valid_class(net1, testloader, classes)
    class_correct2, class_total2 = valid_class(net2, testloader, classes)
    
    accuracies1 = []
    accuracies2 = []
    
    for i in range(len(classes)):
        accuracy1 = 100 * class_correct1[i] / class_total1[i]
        accuracy2 = 100 * class_correct2[i] / class_total2[i]
        
        accuracies1.append(accuracy1)
        accuracies2.append(accuracy2)
        
    # Plotting
    plt.figure(figsize=(10, 6))
    plt.plot(classes, accuracies1, marker='o', label=f'{net1.__class__.__name__}')
    plt.plot(classes, accuracies2, marker='x', label=f'{net2.__class__.__name__}')
    plt.xlabel('Classes')
    plt.ylabel('Accuracy (%)')
    plt.title('Class-wise Accuracy Comparison')
    plt.legend()
    plt.grid(True)
    plt.show()

    return accuracies1, accuracies2

# %%
def train(net, train_loader, epochs=100, optim = optim.SGD, lr=1e-4, print_interval=2000, print_epoch_stats=False):
    """
    Trains the provided network using the given training data loader.

    Args:
        net (nn.Module): The neural network to be trained.
        train_loader (DataLoader): The data loader for the training dataset.
        epochs (int, optional): The number of epochs to train for. Default is 100.
        lr (float, optional): The learning rate for the optimizer. Default is 0.001.
        momentum (float, optional): The momentum for the optimizer. Default is 0.9.
        print_interval (int, optional): The interval (in mini-batches) at which to print the training loss. Default is 2000.
        print_epoch_stats (bool, optional): Whether to print statistics at the end of each epoch. Default is False.

    Returns:
        None
    """
    
    # Determine the device to use
    device = torch.device('cuda') if torch.cuda.is_available() else (torch.device('mps') if torch.backends.mps.is_available() else torch.device('cpu'))
    print(f'Training on {device}')

    # Move the network to the device
    net.to(device)

    # Set up the loss function
    criterion = nn.CrossEntropyLoss()
    optimizer = optim(net.parameters(), lr=lr)

    # Training
    net.train()
    for epoch in range(epochs):

        running_loss = 0.0
        correct = 0
        total = 0

        for i, data in enumerate(train_loader, 0):
            inputs, labels = data
            inputs, labels = inputs.to(device).float(), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.item()

            # Accuracy computation
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            
            if i % print_interval == print_interval - 1:    # print every `print_interval` mini-batches
                print('[%d, %5d] loss: %.10f' %
                    (epoch + 1, i + 1, running_loss / print_interval))
                running_loss = 0.0

        wandb.log({"Training Loss / Step": loss.item()}) # log the last loss of the epoch
        wandb.log({"Training Accuracy / Step": 100 * correct / total})
        wandb.log({"Learning Rate": optimizer.param_groups[0]['lr']})
        wandb.log({"Epoch": epoch + 1})

        if print_epoch_stats:   # print every epoch stats if toggled
            epoch_loss = running_loss / len(train_loader)
            epoch_acc = 100 * correct / total
            print(f'Epoch {epoch + 1} Summary: Loss: {epoch_loss:.3f}, Accuracy: {epoch_acc:.2f}%')
            wandb.log({"Training Loss / Epoch": epoch_loss}) # log the last loss of the epoch
            wandb.log({"Training Accuracy / Epoch": epoch_acc})
        
    print('Finished Training')

# %% [markdown]
# *Initialize the datasets*

# %%
# Datasets
train_set = CIFAR100_loader('./data', True, transform_train)
test_set = CIFAR100_loader('./data', False, transform_test)

# Initialize the dataloaders
train_data_loader = DataLoader(train_set, batch_size=64, shuffle=True, num_workers=0)
test_data_loader = DataLoader(test_set, batch_size=64, shuffle=False, num_workers=0)

# %% [markdown]
# *Train the TwolayerNet network*

# %%
#Initialize the network
nn_net = TwoLayerNet(3*32*32, 512, 100)

# Train the network
wandb.init(
      # Set the project where this run will be logged
      project="2LP - Baseline", 
      # We pass a run name (otherwise it’ll be randomly assigned, like sunshine-lollypop-10)
      name=f"experiment_{1}", 
      # Track hyperparameters and run metadata
      config={
      "Learning Rate": 1e-4,
      "Architecture": "2LP",
      "Dataset": "CIFAR-100",
      "Epochs": 100,
      "Batch Size": 64,
      "Optimizer": "SGD",
      })
train(nn_net, train_data_loader, print_epoch_stats=True, epochs=100)
wandb.finish()

# %% [markdown]
# *Train the ConvNet network*

# %%
# Initialize the network
convnet = ConvNet()

wandb.init(
      # Set the project where this run will be logged
      project="ConvNet - Baseline", 
      # We pass a run name (otherwise it’ll be randomly assigned, like sunshine-lollypop-10)
      name=f"experiment_{1}", 
      # Track hyperparameters and run metadata
      config={
      "Learning Rate": 1e-4,
      "Architecture": "ConvNet",
      "Dataset": "CIFAR-100",
      "Epochs": 100,
      "Batch Size": 64,
      "Optimizer": "SGD",
      })
# Train the network
train(convnet, train_data_loader, print_epoch_stats=True, epochs=100)
wandb.finish()

# %%
wandb.init(
      # Set the project where this run will be logged
      project="2LP - Baseline", 
      # We pass a run name (otherwise it’ll be randomly assigned, like sunshine-lollypop-10)
      name=f"experiment_{1}_test", 
      # Track hyperparameters and run metadata
      config={
      "Learning Rate": 1e-4,
      "Architecture": "2LP",
      "Dataset": "CIFAR-100",
      "Epochs": 1,
      "Batch Size": 64,
      "Optimizer": "SGD",
      "Test": "True"
      })
valid(nn_net, test_data_loader)
wandb.log({"Test Accuracy": valid(nn_net, test_data_loader)})

class_correct, class_total = valid_class(nn_net, test_data_loader, classes)

for i in range(len(classes)):
        print('Accuracy of %5s : %2d %%' % (
            classes[i], 100 * class_correct[i] / class_total[i]))
        wandb.log({"Test Accuracy / Class": 100 * class_correct[i] / class_total[i]})

wandb.finish()

# %%
wandb.init(
      # Set the project where this run will be logged
      project="ConvNet - Baseline", 
      # We pass a run name (otherwise it’ll be randomly assigned, like sunshine-lollypop-10)
      name=f"experiment_{1}_test", 
      # Track hyperparameters and run metadata
      config={
      "Learning Rate": 1e-4,
      "Architecture": "ConvNet",
      "Dataset": "CIFAR-100",
      "Epochs": 1,
      "Batch Size": 64,
      "Optimizer": "SGD",
      "Test": "True"
      })

valid(convnet, test_data_loader)
wandb.log({"Test Accuracy": valid(convnet, test_data_loader)})

class_correct, class_total = valid_class(convnet, test_data_loader, classes)

for i in range(len(classes)):
        print('Accuracy of %5s : %2d %%' % (
            classes[i], 100 * class_correct[i] / class_total[i]))
        wandb.log({"Test Accuracy / Class": 100 * class_correct[i] / class_total[i]})

wandb.finish()

# %%
compare_classifiers(nn_net, convnet, test_data_loader, classes)

# %% [markdown]
# ### **Reporting: function definition**

# %%
from sklearn.metrics import *
import pandas as pd
from datetime import datetime  

def test_label_predictions(model, test_loader):
    model.eval()
    device = torch.device('cuda') if torch.cuda.is_available() else (torch.device('mps') if torch.backends.mps.is_available() else torch.device('cpu'))
    actuals = []
    predictions = []
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device).float(), target.to(device)
            output = model(data)
            prediction = output.argmax(dim=1, keepdim=True)
            actuals.extend(target.view_as(prediction))
            predictions.extend(prediction)
    return [i.item() for i in actuals], [i.item() for i in predictions]

def reporter(model, testloader, model_name = None):
    if model_name == None:
        model_name = model.__class__.__name__
    device = torch.device('cuda') if torch.cuda.is_available() else (torch.device('mps') if torch.backends.mps.is_available() else torch.device('cpu'))
    y_test, y_pred = test_label_predictions(model, testloader) # only pass two arguments
    cm=confusion_matrix(y_test, y_pred)
    cr=classification_report(y_test, y_pred)
    fs=f1_score(y_test,y_pred,average='weighted')
    rs=recall_score(y_test, y_pred,average='weighted')
    accuracy=accuracy_score(y_test, y_pred)
    print(f'Confusion matrix for {model_name}:')
    print(cm)
    print(cr)
    print('F1 score: %f' % fs)
    print('Recall score: %f' % rs)
    print('Accuracy score: %f' % accuracy)
    report = classification_report(y_test, y_pred, output_dict = True)
    df=pd.DataFrame(report).transpose()
    time = datetime.now().strftime("%Y%m%d-%H%M%S")
    df.to_csv(f'classificationreport_{model_name}_{time}.csv',index=False)
    
    return cm, fs, rs, accuracy
    
def plot_confusion_matrix(cm, model_name):
    plt.figure()
    plt.imshow(cm, interpolation='nearest', cmap=plt.get_cmap('Blues'))
    plt.colorbar()
    plt.ylabel('True label', fontsize=14)
    plt.xlabel('Predicted label', fontsize=14)
    plt.tight_layout()
    time = datetime.now().strftime("%Y%m%d-%H%M%S")
    plt.savefig(f"confusion_matrix_{model_name}_{time}.pdf")
    plt.show()

def plot_classification(precision, recall, f1_score, model_name):
    plt.rcParams['font.size'] = 12
    plt.rc('axes', linewidth=1.75)
    marker_size = 8
    figsize = 6
    plt.figure(figsize=(1.4 * figsize, figsize))
    plt.subplot(3, 1, 1)
    plt.plot(precision, 'o', markersize=marker_size)
    # plt.legend(loc=0)
    # plt.yticks(np.arange(0.5, 1.01, 0.1))
    plt.ylabel('Precision', fontsize=14)
    plt.xticks([])
    plt.subplot(3, 1, 2)
    plt.plot(recall, 'o', markersize=marker_size)
    # plt.yticks(np.arange(0.5, 1.01, 0.1))
    plt.ylabel('Recall', fontsize=14)
    plt.xticks([])
    plt.subplot(3, 1, 3)
    plt.plot(f1_score, 'o', markersize=marker_size)
    # plt.yticks(np.arange(0.5, 1.01, 0.1))
    plt.ylabel('F1-score', fontsize=14)
    plt.xlabel('Class', fontsize=14)
    plt.subplots_adjust(hspace=0.001)
    plt.tight_layout()
    time = datetime.now().strftime("%Y%m%d-%H%M%S")
    plt.savefig(f"classification_{model_name}_{time}.pdf")

# %% [markdown]
# ### **2LP Report**

# %%
cm, fs, rs, accuracy = reporter(nn_net, test_data_loader)

# %%
y_train, y_pred2 = test_label_predictions(nn_net, train_data_loader)
y_test, y_pred = test_label_predictions(nn_net, test_data_loader)
train_accuracy=accuracy_score(y_train, y_pred2)
print('Train accuracy: %f' % train_accuracy)

# %%
precision, recall, f1,_= precision_recall_fscore_support(y_test, y_pred)
print(recall)
plot_classification(precision, recall, f1, "TwoLayerNet")

# Plot confusion matrix
plot_confusion_matrix(cm, "TwoLayerNet")

# %% [markdown]
# ### **LeNet-5 Report**

# %%
cm, fs, rs, accuracy = reporter(convnet, test_data_loader)

# %%
y_train, y_pred2 = test_label_predictions(convnet, train_data_loader)
y_test, y_pred = test_label_predictions(convnet, test_data_loader)
train_accuracy=accuracy_score(y_train, y_pred2)
print('Train accuracy: %f' % train_accuracy)

# %%
precision, recall, f1,_= precision_recall_fscore_support(y_test, y_pred)
print(recall)
plot_classification(precision, recall, f1, "LeNet-5")

# Plot confusion matrix
plot_confusion_matrix(cm, "LeNet-5")

# %%
for r in range(1, 13):
    #Initialize the network
    nn_net = TwoLayerNet(3*32*32, 512, 100)

    # Train the network
    wandb.init(
        # Set the project where this run will be logged
        project="2LP - Baseline", 
        # We pass a run name (otherwise it’ll be randomly assigned, like sunshine-lollypop-10)
        name=f"experiment_{r}", 
        # Track hyperparameters and run metadata
        config={
        "Learning Rate": 1e-4,
        "Architecture": "2LP",
        "Dataset": "CIFAR-100",
        "Epochs": 100,
        "Batch Size": 64,
        "Optimizer": "SGD",
        })
    train(nn_net, train_data_loader, print_epoch_stats=True, epochs=100)
    wandb.finish()

    wandb.init(
      # Set the project where this run will be logged
      project="2LP - Baseline", 
      # We pass a run name (otherwise it’ll be randomly assigned, like sunshine-lollypop-10)
      name=f"experiment_{r}_test", 
      # Track hyperparameters and run metadata
      config={
      "Learning Rate": 1e-4,
      "Architecture": "2LP",
      "Dataset": "CIFAR-100",
      "Epochs": 1,
      "Batch Size": 64,
      "Optimizer": "SGD",
      "Test": "True"
      })
    valid(nn_net, test_data_loader)
    wandb.log({"Test Accuracy": valid(nn_net, test_data_loader)})

    class_correct, class_total = valid_class(nn_net, test_data_loader, classes)

    for i in range(len(classes)):
            print('Accuracy of %5s : %2d %%' % (
                classes[i], 100 * class_correct[i] / class_total[i]))
            wandb.log({"Test Accuracy / Class": 100 * class_correct[i] / class_total[i]})

    wandb.finish()

# %%
for r in range(1, 13):
    #Initialize the network
    convnet = ConvNet()

    wandb.init(
        # Set the project where this run will be logged
        project="ConvNet - Baseline", 
        # We pass a run name (otherwise it’ll be randomly assigned, like sunshine-lollypop-10)
        name=f"experiment_{r}", 
        # Track hyperparameters and run metadata
        config={
        "Learning Rate": 1e-4,
        "Architecture": "ConvNet",
        "Dataset": "CIFAR-100",
        "Epochs": 100,
        "Batch Size": 64,
        "Optimizer": "SGD",
        })
    # Train the network
    train(convnet, train_data_loader, print_epoch_stats=True, epochs=100)
    wandb.finish()

    wandb.init(
      # Set the project where this run will be logged
      project="ConvNet - Baseline", 
      # We pass a run name (otherwise it’ll be randomly assigned, like sunshine-lollypop-10)
      name=f"experiment_{r}_test", 
      # Track hyperparameters and run metadata
      config={
      "Learning Rate": 1e-4,
      "Architecture": "ConvNet",
      "Dataset": "CIFAR-100",
      "Epochs": 1,
      "Batch Size": 64,
      "Optimizer": "SGD",
      "Test": "True"
      })

    valid(convnet, test_data_loader)
    wandb.log({"Test Accuracy": valid(convnet, test_data_loader)})

    class_correct, class_total = valid_class(convnet, test_data_loader, classes)

    for i in range(len(classes)):
            print('Accuracy of %5s : %2d %%' % (
                classes[i], 100 * class_correct[i] / class_total[i]))
            wandb.log({"Test Accuracy / Class": 100 * class_correct[i] / class_total[i]})

    wandb.finish()

# %% [markdown]
# ### 1.4 Setting up the hyperparameters
#
# Some parameters must be set properly before the training of CNNs. These parameters shape the training procedure. They determine how many images are to be processed at each step, how much the weights of the network will be updated, how many iterations will the network run until convergence.  These parameters are called hyperparameters in the machine learning literature.

# %% [markdown]
# ####  **` Q1.4: Setting up the hyperparameters (10-pts)`**
#
# 1. Play with ConvNet and TwolayerNet yourself, set up the hyperparameters, and reach the accuracy as high as you can.
# You can modify the *train*,  *Dataloader*, *transform* and *Optimizer* function as you like.
# 2. You can also modify the architectures of these two Nets. *Let's add 2 more layers in TwolayerNet and ConvNet, and show the results. (You can decide the size of these layers and where to add them.) Will you get higher performances? explain why.*
# 3.  Show the final results and described what you've done to improve the results. Describe and explain the influence of hyperparameters among *TwolayerNet* and *ConvNet*.
# 4. Compare and explain the differences of these two networks regarding the architecture, performances, and learning rates.
#
# **Hint:** You can adjust the following parameters and other parameters not listed as you like: *Learning rate, Batch size, Number of epochs, Optimizer, Transform function, Weight decay etc.* You can also change the structure a bit, for instance, adding Batch Normalization layers.
#
# **Note:** Please do not use external well-defined networks and please do not add more than 3 additional (beyond the original network) convolutional layers.

# %% [markdown]
# ## **No layer addition**

# %%
import random
random.seed(42) # set the seed for reproducibility

# %%
transform_train = transforms.Compose([
    transforms.ToImage(),
    transforms.ToDtype(torch.float32, scale=True),
    transforms.RandomHorizontalFlip(0.1),
    transforms.RandomRotation(20),
    transforms.RandomAdjustSharpness(sharpness_factor = 2, p = 0.1),
    transforms.ColorJitter(brightness = 0.1, contrast = 0.1, saturation = 0.1),
    transforms.Normalize((0.5070751592371323, 0.48654887331495095, 0.4409178433670343), (0.2673342858792401, 0.2564384629170883, 0.27615047132568404)), # normalize
])

transform_test = transforms.Compose([
    transforms.ToImage(),
    transforms.ToDtype(torch.float32, scale=True),
    transforms.Normalize((0.5088964127604166, 0.48739301317401956, 0.44194221124387256), (0.2682515741720801, 0.2573637364478126, 0.2770957707973042))
])


# Datasets
train_set = CIFAR100_loader('./data', True, transform_train)
test_set = CIFAR100_loader('./data', False, transform_test)

# Initialize the dataloaders
train_data_loader = DataLoader(train_set, batch_size=64, shuffle=True, num_workers=0)
test_data_loader = DataLoader(test_set, batch_size=64, shuffle=False, num_workers=0)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def train(net, train_loader, epochs=100, lr=1e-4, print_interval=2000, print_epoch_stats=False, optimizer_name = "SGD", momentum = 0.9, weight_decay = 0.0, clip_value = 0.1):
    """
    Trains the provided network using the given training data loader.

    Args:
        net (nn.Module): The neural network to be trained.
        train_loader (DataLoader): The data loader for the training dataset.
        epochs (int, optional): The number of epochs to train for. Default is 100.
        lr (float, optional): The learning rate for the optimizer. Default is 0.001.
        momentum (float, optional): The momentum for the optimizer. Default is 0.9.
        print_interval (int, optional): The interval (in mini-batches) at which to print the training loss. Default is 2000.
        print_epoch_stats (bool, optional): Whether to print statistics at the end of each epoch. Default is False.

    Returns:
        None
    """
    
    # Determine the device to use
    device = torch.device('cuda') if torch.cuda.is_available() else (torch.device('mps') if torch.backends.mps.is_available() else torch.device('cpu'))
    print(f'Training on {device}')

    # Move the network to the device
    net.to(device)

    # Set up the loss function
    criterion = nn.CrossEntropyLoss()
    if optimizer_name == "SGD":
        print("Using CyclicLR") 
        optimizer = optim.SGD(net.parameters(), lr=lr, momentum=momentum, weight_decay=weight_decay)
        scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=(lr*100), steps_per_epoch=len(train_loader), epochs=epochs)
    else:
        print("Using Adam")
        optimizer = optim.Adam(net.parameters(), lr= 3 * lr, weight_decay=weight_decay)

    # Training
    net.train()
    for epoch in range(epochs):

        running_loss = 0.0
        correct = 0
        total = 0

        for i, data in enumerate(train_loader, 0):
            inputs, labels = data
            inputs, labels = inputs.to(device).float(), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            torch.nn.utils.clip_grad_norm_(net.parameters(), clip_value)
            if optimizer_name == "SGD":
                #print("Using OneCycleLR - Step")
                scheduler.step()

            # print statistics
            running_loss += loss.item()
            wandb.log({"Training Loss / Step": loss.item()}) 

            # Accuracy computation
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            
            if i % print_interval == print_interval - 1:    # print every `print_interval` mini-batches
                print('[%d, %5d] loss: %.10f' %
                    (epoch + 1, i + 1, running_loss / print_interval))
                running_loss = 0.0

        wandb.log({"Training Loss": running_loss / len(train_loader)}) # log the last loss of the epoch
        wandb.log({"Training Accuracy": 100 * correct / total})
        wandb.log({"Learning Rate": optimizer.param_groups[0]['lr']})
        wandb.log({"Epoch": epoch + 1})

        if print_epoch_stats:   # print every epoch stats if toggled
            epoch_loss = running_loss / len(train_loader)
            epoch_acc = 100 * correct / total
            if optimizer_name == "SGD":
                print(f'Epoch {epoch + 1} Summary: Loss: {epoch_loss:.3f}, Accuracy: {epoch_acc:.2f}%, lr: {scheduler.get_last_lr()}')
            else:
                print(f'Epoch {epoch + 1} Summary: Loss: {epoch_loss:.3f}, Accuracy: {epoch_acc:.2f}%, lr: {lr}')

    print('Finished Training')

# %% [markdown]
# #### *`Play with convNet and TwolayerNet, set up the hyperparameters and reach the accuracy as high as you can`*

# %%
#Initialize the network
nn_net = TwoLayerNet(3*32*32, 1024, 100)

# Train the network
wandb.init(
      # Set the project where this run will be logged
      project="2LP - Hyperparameter Tuning", 
      # We pass a run name (otherwise it’ll be randomly assigned, like sunshine-lollypop-10)
      name=f"experiment_{1}", 
      # Track hyperparameters and run metadata
      config={
      "Learning Rate": "1CycleLR - 1e-4 min 1e-3",
      "Architecture": "2LP",
      "Dataset": "CIFAR-100",
      "Epochs": 100,
      "Batch Size": 64,
      "Optimizer": "SGD with Momentum",
      "Weight Decay": 0.01,
      "Transformations": "True"
      })
train(nn_net, train_data_loader, print_epoch_stats=True, epochs=100, optimizer_name = "SGD", weight_decay = 0.001, lr=1e-5)
wandb.finish()
# Out:
# Finishing last run (ID:jh0lsm73) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Epoch</td><td>▁▂▃▄▅▅▆▇█</td></tr><tr><td>Learning Rate</td><td>▁▁▂▂▃▄▅▇█</td></tr><tr><td>Training Accuracy</td><td>▁▄▆██▆▇▄▃</td></tr><tr><td>Training Loss</td><td>█▁▁▁▁▁▁▁▁</td></tr><tr><td>Training Loss / Step</td><td>█▆▆▆▅▄▅▄▅▄▂▄▄▄▄▄▄▂▂▃▃▁▄▄▅▄▄▂▄▇▅▆▅▆▃▅▅▆▆▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Epoch</td><td>9</td></tr><tr><td>Learning Rate</td><td>0.00024</td></tr><tr><td>Training Accuracy</td><td>3.108</td></tr><tr><td>Training Loss</td><td>4.49347</td></tr><tr><td>Training Loss / Step</td><td>4.52527</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">experiment_1</strong> at: <a href='https://wandb.ai/1000kelvin/2LP%20-%20Hyperparameter%20Tuning/runs/jh0lsm73' target="_blank">https://wandb.ai/1000kelvin/2LP%20-%20Hyperparameter%20Tuning/runs/jh0lsm73</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231021_195709-jh0lsm73/logs</code>
# Successfully finished last run (ID:jh0lsm73). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113313433331011, max=1.0…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/Users/joanvelja/Desktop/UvA AI/Computer Vision 1/Assignments/Lab5 Final/wandb/run-20231021_195758-t6oklyv7</code>
# Syncing run <strong><a href='https://wandb.ai/1000kelvin/2LP%20-%20Hyperparameter%20Tuning/runs/t6oklyv7' target="_blank">experiment_1</a></strong> to <a href='https://wandb.ai/1000kelvin/2LP%20-%20Hyperparameter%20Tuning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/1000kelvin/2LP%20-%20Hyperparameter%20Tuning' target="_blank">https://wandb.ai/1000kelvin/2LP%20-%20Hyperparameter%20Tuning</a>
#  View run at <a href='https://wandb.ai/1000kelvin/2LP%20-%20Hyperparameter%20Tuning/runs/t6oklyv7' target="_blank">https://wandb.ai/1000kelvin/2LP%20-%20Hyperparameter%20Tuning/runs/t6oklyv7</a>
# Training on mps
# Using CyclicLR
# Epoch 1 Summary: Loss: 7.710, Accuracy: 2.30%, lr: [4.262971420060271e-06]
# Epoch 2 Summary: Loss: 4.543, Accuracy: 3.57%, lr: [5.04900426491737e-06]
# Epoch 3 Summary: Loss: 4.416, Accuracy: 4.88%, lr: [6.34948586067857e-06]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>Learning Rate</td><td>▁▁▂▂▃▄▅▆▇▇███████▇▇▇▇▆▆▅▅▅▄▄▃▃▃▂▂▂▂▁▁▁▁▁</td></tr><tr><td>Training Accuracy</td><td>▁▁▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇██████</td></tr><tr><td>Training Loss</td><td>█▄▄▄▄▃▃▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Training Loss / Step</td><td>██▇▇▆▅▆▆▅▅▅▅▅▄▅▄▅▄▄▅▃▃▃▄▃▃▃▂▃▃▃▂▂▂▂▂▁▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Epoch</td><td>100</td></tr><tr><td>Learning Rate</td><td>0.0</td></tr><tr><td>Training Accuracy</td><td>68.668</td></tr><tr><td>Training Loss</td><td>1.30336</td></tr><tr><td>Training Loss / Step</td><td>1.51552</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">experiment_1</strong> at: <a href='https://wandb.ai/1000kelvin/2LP%20-%20Hyperparameter%20Tuning/runs/t6oklyv7' target="_blank">https://wandb.ai/1000kelvin/2LP%20-%20Hyperparameter%20Tuning/runs/t6oklyv7</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231021_195758-t6oklyv7/logs</code>

# %%
#Initialize the network
convnet = ConvNet()

# Train the network
wandb.init(
      # Set the project where this run will be logged
      project="ConvNetOG - Hyperparameter Tuning", 
      # We pass a run name (otherwise it’ll be randomly assigned, like sunshine-lollypop-10)
      name=f"experiment_{2}", 
      # Track hyperparameters and run metadata
      config={
      "Learning Rate": "1CycleLR - 2e-3 to 2e-2",
      "Architecture": "ConvNetOG",
      "Dataset": "CIFAR-100",
      "Epochs": 100,
      "Batch Size": 64,
      "Optimizer": "SGD with Momentum",
      "Weight Decay": 0.01,
      "Transformations": "True"
      })
train(convnet, train_data_loader, print_epoch_stats=True, epochs=100, optimizer_name = "SGD", weight_decay = 0.001, lr=2e-3, clip_value=1)
wandb.finish()
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011156334255550368, max=1.0…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/Users/joanvelja/Desktop/UvA AI/Computer Vision 1/Assignments/Lab5 Final/wandb/run-20231021_200427-yr7vjl04</code>
# Syncing run <strong><a href='https://wandb.ai/1000kelvin/ConvNetOG%20-%20Hyperparameter%20Tuning/runs/yr7vjl04' target="_blank">experiment_2</a></strong> to <a href='https://wandb.ai/1000kelvin/ConvNetOG%20-%20Hyperparameter%20Tuning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/1000kelvin/ConvNetOG%20-%20Hyperparameter%20Tuning' target="_blank">https://wandb.ai/1000kelvin/ConvNetOG%20-%20Hyperparameter%20Tuning</a>
#  View run at <a href='https://wandb.ai/1000kelvin/ConvNetOG%20-%20Hyperparameter%20Tuning/runs/yr7vjl04' target="_blank">https://wandb.ai/1000kelvin/ConvNetOG%20-%20Hyperparameter%20Tuning/runs/yr7vjl04</a>
# Training on mps
# Using CyclicLR
# Epoch 1 Summary: Loss: 4.537, Accuracy: 2.09%, lr: [0.0008525942840120516]
# Epoch 2 Summary: Loss: 4.370, Accuracy: 3.33%, lr: [0.0010098008529834737]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>Learning Rate</td><td>▁▁▂▂▃▄▅▆▇▇███████▇▇▇▇▆▆▅▅▅▄▄▃▃▃▂▂▂▂▁▁▁▁▁</td></tr><tr><td>Training Accuracy</td><td>▁▂▃▃▄▄▄▄▅▄▅▅▅▅▅▅▅▆▆▆▅▆▆▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>Training Loss</td><td>█▇▆▆▅▅▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>Training Loss / Step</td><td>██▆▆▆▆▅▄▅▅▃▄▅▃▄▄▂▂▄▃▅▂▃▅▄▅▄▅▄▃▃▂▂▂▂▂▂▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Epoch</td><td>100</td></tr><tr><td>Learning Rate</td><td>0.0</td></tr><tr><td>Training Accuracy</td><td>40.164</td></tr><tr><td>Training Loss</td><td>2.38681</td></tr><tr><td>Training Loss / Step</td><td>2.76044</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">experiment_2</strong> at: <a href='https://wandb.ai/1000kelvin/ConvNetOG%20-%20Hyperparameter%20Tuning/runs/yr7vjl04' target="_blank">https://wandb.ai/1000kelvin/ConvNetOG%20-%20Hyperparameter%20Tuning/runs/yr7vjl04</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231021_200427-yr7vjl04/logs</code>

# %% [markdown]
# #### *` Test the accuracy of ConvNet `*

# %%
wandb.init(
      # Set the project where this run will be logged
      project="ConvNetOG - Hyperparameter Tuning", 
      # We pass a run name (otherwise it’ll be randomly assigned, like sunshine-lollypop-10)
      name=f"experiment_{2}_test", 
      # Track hyperparameters and run metadata
      config={
      "Learning Rate": "1CycleLR - 2e-3 to 2e-2",
      "Architecture": "ConvNetOG",
      "Dataset": "CIFAR-100",
      "Epochs": 1,
      "Batch Size": 64,
      "Optimizer": "SGD with Momentum",
      "Weight Decay": 0.01,
      "Transformations": "True",
      "Clip Value": 1,
      "Test": "True"
      })
      
valid(convnet, test_data_loader)
wandb.log({"Test Accuracy": valid(convnet, test_data_loader)})

class_correct, class_total = valid_class(convnet, test_data_loader, classes)

for i in range(len(classes)):
        print('Accuracy of %5s : %2d %%' % (
            classes[i], 100 * class_correct[i] / class_total[i]))
        wandb.log({"Test Accuracy / Class": 100 * class_correct[i] / class_total[i]})

wandb.finish()
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011163339355577288, max=1.0…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/Users/joanvelja/Desktop/UvA AI/Computer Vision 1/Assignments/Lab5 Final/wandb/run-20231021_201435-1mcshd9o</code>
# Syncing run <strong><a href='https://wandb.ai/1000kelvin/ConvNetOG%20-%20Hyperparameter%20Tuning/runs/1mcshd9o' target="_blank">experiment_2_test</a></strong> to <a href='https://wandb.ai/1000kelvin/ConvNetOG%20-%20Hyperparameter%20Tuning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/1000kelvin/ConvNetOG%20-%20Hyperparameter%20Tuning' target="_blank">https://wandb.ai/1000kelvin/ConvNetOG%20-%20Hyperparameter%20Tuning</a>
#  View run at <a href='https://wandb.ai/1000kelvin/ConvNetOG%20-%20Hyperparameter%20Tuning/runs/1mcshd9o' target="_blank">https://wandb.ai/1000kelvin/ConvNetOG%20-%20Hyperparameter%20Tuning/runs/1mcshd9o</a>
# Accuracy of the network on the 10000 test images: 29 %
# Accuracy of the network on the 10000 test images: 29 %
# Accuracy of apple : 58 %
# Accuracy of aquarium_fish : 40 %
# Accuracy of  baby : 17 %
# Accuracy of  bear : 17 %
# Accuracy of beaver :  7 %
# Accuracy of   bed : 31 %
# Accuracy of   bee : 22 %
# Accuracy of beetle : 28 %
# Accuracy of bicycle : 41 %
# Accuracy of bottle : 41 %
# Accuracy of  bowl : 12 %
# Accuracy of   boy : 11 %
# Accuracy of bridge : 31 %
# Accuracy of   bus : 26 %
# Accuracy of butterfly : 22 %
# Accuracy of camel : 22 %
# Accuracy of   can : 25 %
# Accuracy of castle : 43 %
# Accuracy of caterpillar : 25 %
# Accuracy of cattle : 21 %
# Accuracy of chair : 60 %
# Accuracy of chimpanzee : 47 %
# Accuracy of clock : 20 %
# Accuracy of cloud : 50 %
# Accuracy of cockroach : 67 %
# Accuracy of couch : 22 %
# Accuracy of   cra : 15 %
# Accuracy of crocodile : 21 %
# Accuracy of   cup : 44 %
# Accuracy of dinosaur : 30 %
# Accuracy of dolphin : 36 %
# Accuracy of elephant : 32 %
# Accuracy of flatfish : 24 %
# Accuracy of forest : 23 %
# Accuracy of   fox : 17 %
# Accuracy of  girl : 14 %
# Accuracy of hamster : 23 %
# Accuracy of house : 22 %
# Accuracy of kangaroo : 19 %
# Accuracy of keyboard : 40 %
# Accuracy of  lamp : 25 %
# Accuracy of lawn_mower : 51 %
# Accuracy of leopard : 14 %
# Accuracy of  lion : 31 %
# Accuracy of lizard : 13 %
# Accuracy of lobster :  7 %
# Accuracy of   man : 19 %
# Accuracy of maple_tree : 37 %
# Accuracy of motorcycle : 51 %
# Accuracy of mountain : 41 %
# Accuracy of mouse :  8 %
# Accuracy of mushroom : 24 %
# Accuracy of oak_tree : 58 %
# Accuracy of orange : 53 %
# Accuracy of orchid : 35 %
# Accuracy of otter :  2 %
# Accuracy of palm_tree : 45 %
# Accuracy of  pear : 26 %
# Accuracy of pickup_truck : 41 %
# Accuracy of pine_tree : 19 %
# Accuracy of plain : 69 %
# Accuracy of plate : 34 %
# Accuracy of poppy : 41 %
# Accuracy of porcupine : 29 %
# Accuracy of possum :  7 %
# Accuracy of rabbit : 11 %
# Accuracy of raccoon :  9 %
# Accuracy of   ray : 21 %
# Accuracy of  road : 68 %
# Accuracy of rocket : 44 %
# Accuracy of  rose : 37 %
# Accuracy of   sea : 50 %
# Accuracy of  seal :  4 %
# Accuracy of shark : 33 %
# Accuracy of shrew : 13 %
# Accuracy of skunk : 47 %
# Accuracy of skyscraper : 56 %
# Accuracy of snail : 17 %
# Accuracy of snake :  7 %
# Accuracy of spider : 17 %
# Accuracy of squirrel :  2 %
# Accuracy of streetcar : 21 %
# Accuracy of sunflower : 58 %
# Accuracy of sweet_pepper : 17 %
# Accuracy of table : 17 %
# Accuracy of  tank : 37 %
# Accuracy of telephone : 34 %
# Accuracy of television : 31 %
# Accuracy of tiger : 17 %
# Accuracy of tractor : 34 %
# Accuracy of train : 20 %
# Accuracy of trout : 37 %
# Accuracy of tulip : 13 %
# Accuracy of turtle : 11 %
# Accuracy of wardrobe : 58 %
# Accuracy of whale : 49 %
# Accuracy of willow_tree : 25 %
# Accuracy of  wolf : 29 %
# Accuracy of woman :  9 %
# Accuracy of  worm : 14 %
# Accuracy of apple : 58 %
# Accuracy of aquarium_fish : 40 %
# Accuracy of  baby : 17 %
# Accuracy of  bear : 17 %
# Accuracy of beaver :  7 %
# Accuracy of   bed : 31 %
# Accuracy of   bee : 22 %
# Accuracy of beetle : 28 %
# Accuracy of bicycle : 41 %
# Accuracy of bottle : 41 %
# Accuracy of  bowl : 12 %
# Accuracy of   boy : 11 %
# Accuracy of bridge : 31 %
# Accuracy of   bus : 26 %
# Accuracy of butterfly : 22 %
# Accuracy of camel : 22 %
# Accuracy of   can : 25 %
# Accuracy of castle : 43 %
# Accuracy of caterpillar : 25 %
# Accuracy of cattle : 21 %
# Accuracy of chair : 60 %
# Accuracy of chimpanzee : 47 %
# Accuracy of clock : 20 %
# Accuracy of cloud : 50 %
# Accuracy of cockroach : 67 %
# Accuracy of couch : 22 %
# Accuracy of   cra : 15 %
# Accuracy of crocodile : 21 %
# Accuracy of   cup : 44 %
# Accuracy of dinosaur : 30 %
# Accuracy of dolphin : 36 %
# Accuracy of elephant : 32 %
# Accuracy of flatfish : 24 %
# Accuracy of forest : 23 %
# Accuracy of   fox : 17 %
# Accuracy of  girl : 14 %
# Accuracy of hamster : 23 %
# Accuracy of house : 22 %
# Accuracy of kangaroo : 19 %
# Accuracy of keyboard : 40 %
# Accuracy of  lamp : 25 %
# Accuracy of lawn_mower : 51 %
# Accuracy of leopard : 14 %
# Accuracy of  lion : 31 %
# Accuracy of lizard : 13 %
# Accuracy of lobster :  7 %
# Accuracy of   man : 19 %
# Accuracy of maple_tree : 37 %
# Accuracy of motorcycle : 51 %
# Accuracy of mountain : 41 %
# Accuracy of mouse :  8 %
# Accuracy of mushroom : 24 %
# Accuracy of oak_tree : 58 %
# Accuracy of orange : 53 %
# Accuracy of orchid : 35 %
# Accuracy of otter :  2 %
# Accuracy of palm_tree : 45 %
# Accuracy of  pear : 26 %
# Accuracy of pickup_truck : 41 %
# Accuracy of pine_tree : 19 %
# Accuracy of plain : 69 %
# Accuracy of plate : 34 %
# Accuracy of poppy : 41 %
# Accuracy of porcupine : 29 %
# Accuracy of possum :  7 %
# Accuracy of rabbit : 11 %
# Accuracy of raccoon :  9 %
# Accuracy of   ray : 21 %
# Accuracy of  road : 68 %
# Accuracy of rocket : 44 %
# Accuracy of  rose : 37 %
# Accuracy of   sea : 50 %
# Accuracy of  seal :  4 %
# Accuracy of shark : 33 %
# Accuracy of shrew : 13 %
# Accuracy of skunk : 47 %
# Accuracy of skyscraper : 56 %
# Accuracy of snail : 17 %
# Accuracy of snake :  7 %
# Accuracy of spider : 17 %
# Accuracy of squirrel :  2 %
# Accuracy of streetcar : 21 %
# Accuracy of sunflower : 58 %
# Accuracy of sweet_pepper : 17 %
# Accuracy of table : 17 %
# Accuracy of  tank : 37 %
# Accuracy of telephone : 34 %
# Accuracy of television : 31 %
# Accuracy of tiger : 17 %
# Accuracy of tractor : 34 %
# Accuracy of train : 20 %
# Accuracy of trout : 37 %
# Accuracy of tulip : 13 %
# Accuracy of turtle : 11 %
# Accuracy of wardrobe : 58 %
# Accuracy of whale : 49 %
# Accuracy of willow_tree : 25 %
# Accuracy of  wolf : 29 %
# Accuracy of woman :  9 %
# Accuracy of  worm : 14 %
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test Accuracy</td><td>▁</td></tr><tr><td>Test Accuracy / Class</td><td>▇▃▄▄▂▄▃▅▇▃▃▃▅▃▂▃▃▄▂▆▂▆▁▅█▄▂█▆▄▇▂▃▃▄▃▅▂▃▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test Accuracy</td><td>29.13</td></tr><tr><td>Test Accuracy / Class</td><td>14.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">experiment_2_test</strong> at: <a href='https://wandb.ai/1000kelvin/ConvNetOG%20-%20Hyperparameter%20Tuning/runs/1mcshd9o' target="_blank">https://wandb.ai/1000kelvin/ConvNetOG%20-%20Hyperparameter%20Tuning/runs/1mcshd9o</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231021_201435-1mcshd9o/logs</code>

# %% [markdown]
# #### *`Test the accuracy of TwolayerNet`*

# %%
wandb.init(
      # Set the project where this run will be logged
      project="2LP - Hyperparameter Tuning", 
      # We pass a run name (otherwise it’ll be randomly assigned, like sunshine-lollypop-10)
      name=f"experiment_{2}_test", 
      # Track hyperparameters and run metadata
      config={
      "Learning Rate": "1CycleLR - lr=1e-5",
      "Architecture": "2LP",
      "Dataset": "CIFAR-100",
      "Epochs": 1,
      "Batch Size": 64,
      "Optimizer": "SGD with Momentum",
      "Weight Decay": 0.01,
      "Transformations": "True",
      "Test": "True"
      })
      
valid(nn_net, test_data_loader)
wandb.log({"Test Accuracy": valid(nn_net, test_data_loader)})

class_correct, class_total = valid_class(nn_net, test_data_loader, classes)

for i in range(len(classes)):
        print('Accuracy of %5s : %2d %%' % (
            classes[i], 100 * class_correct[i] / class_total[i]))
        wandb.log({"Test Accuracy / Class": 100 * class_correct[i] / class_total[i]})

wandb.finish()
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011167146755582912, max=1.0…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/Users/joanvelja/Desktop/UvA AI/Computer Vision 1/Assignments/Lab5 Final/wandb/run-20231021_201449-wsd8818o</code>
# Syncing run <strong><a href='https://wandb.ai/1000kelvin/2LP%20-%20Hyperparameter%20Tuning/runs/wsd8818o' target="_blank">experiment_2_test</a></strong> to <a href='https://wandb.ai/1000kelvin/2LP%20-%20Hyperparameter%20Tuning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/1000kelvin/2LP%20-%20Hyperparameter%20Tuning' target="_blank">https://wandb.ai/1000kelvin/2LP%20-%20Hyperparameter%20Tuning</a>
#  View run at <a href='https://wandb.ai/1000kelvin/2LP%20-%20Hyperparameter%20Tuning/runs/wsd8818o' target="_blank">https://wandb.ai/1000kelvin/2LP%20-%20Hyperparameter%20Tuning/runs/wsd8818o</a>
# Accuracy of the network on the 10000 test images: 21 %
# Accuracy of the network on the 10000 test images: 21 %
# Accuracy of apple : 50 %
# Accuracy of aquarium_fish : 36 %
# Accuracy of  baby : 13 %
# Accuracy of  bear :  5 %
# Accuracy of beaver :  9 %
# Accuracy of   bed : 19 %
# Accuracy of   bee : 14 %
# Accuracy of beetle : 20 %
# Accuracy of bicycle : 21 %
# Accuracy of bottle : 31 %
# Accuracy of  bowl : 10 %
# Accuracy of   boy : 13 %
# Accuracy of bridge : 13 %
# Accuracy of   bus : 10 %
# Accuracy of butterfly : 14 %
# Accuracy of camel : 12 %
# Accuracy of   can : 19 %
# Accuracy of castle : 41 %
# Accuracy of caterpillar : 16 %
# Accuracy of cattle : 11 %
# Accuracy of chair : 45 %
# Accuracy of chimpanzee : 40 %
# Accuracy of clock : 20 %
# Accuracy of cloud : 49 %
# Accuracy of cockroach : 46 %
# Accuracy of couch :  5 %
# Accuracy of   cra : 10 %
# Accuracy of crocodile : 11 %
# Accuracy of   cup : 38 %
# Accuracy of dinosaur :  9 %
# Accuracy of dolphin : 29 %
# Accuracy of elephant :  8 %
# Accuracy of flatfish : 13 %
# Accuracy of forest : 15 %
# Accuracy of   fox : 15 %
# Accuracy of  girl :  6 %
# Accuracy of hamster : 25 %
# Accuracy of house : 17 %
# Accuracy of kangaroo : 17 %
# Accuracy of keyboard : 17 %
# Accuracy of  lamp : 21 %
# Accuracy of lawn_mower : 48 %
# Accuracy of leopard : 11 %
# Accuracy of  lion : 26 %
# Accuracy of lizard : 13 %
# Accuracy of lobster :  8 %
# Accuracy of   man : 12 %
# Accuracy of maple_tree : 35 %
# Accuracy of motorcycle : 28 %
# Accuracy of mountain : 20 %
# Accuracy of mouse :  4 %
# Accuracy of mushroom : 16 %
# Accuracy of oak_tree : 47 %
# Accuracy of orange : 43 %
# Accuracy of orchid : 24 %
# Accuracy of otter :  6 %
# Accuracy of palm_tree : 30 %
# Accuracy of  pear : 22 %
# Accuracy of pickup_truck : 16 %
# Accuracy of pine_tree : 23 %
# Accuracy of plain : 66 %
# Accuracy of plate : 40 %
# Accuracy of poppy : 30 %
# Accuracy of porcupine : 20 %
# Accuracy of possum :  8 %
# Accuracy of rabbit : 12 %
# Accuracy of raccoon :  4 %
# Accuracy of   ray : 30 %
# Accuracy of  road : 56 %
# Accuracy of rocket : 33 %
# Accuracy of  rose : 27 %
# Accuracy of   sea : 44 %
# Accuracy of  seal :  7 %
# Accuracy of shark : 21 %
# Accuracy of shrew :  8 %
# Accuracy of skunk : 26 %
# Accuracy of skyscraper : 37 %
# Accuracy of snail :  9 %
# Accuracy of snake : 11 %
# Accuracy of spider :  6 %
# Accuracy of squirrel :  4 %
# Accuracy of streetcar : 16 %
# Accuracy of sunflower : 54 %
# Accuracy of sweet_pepper : 16 %
# Accuracy of table : 10 %
# Accuracy of  tank : 29 %
# Accuracy of telephone : 24 %
# Accuracy of television : 26 %
# Accuracy of tiger :  6 %
# Accuracy of tractor : 21 %
# Accuracy of train : 10 %
# Accuracy of trout : 32 %
# Accuracy of tulip : 16 %
# Accuracy of turtle : 11 %
# Accuracy of wardrobe : 39 %
# Accuracy of whale : 27 %
# Accuracy of willow_tree : 25 %
# Accuracy of  wolf : 12 %
# Accuracy of woman :  5 %
# Accuracy of  worm : 28 %
# Accuracy of apple : 50 %
# Accuracy of aquarium_fish : 36 %
# Accuracy of  baby : 13 %
# Accuracy of  bear :  5 %
# Accuracy of beaver :  9 %
# Accuracy of   bed : 19 %
# Accuracy of   bee : 14 %
# Accuracy of beetle : 20 %
# Accuracy of bicycle : 21 %
# Accuracy of bottle : 31 %
# Accuracy of  bowl : 10 %
# Accuracy of   boy : 13 %
# Accuracy of bridge : 13 %
# Accuracy of   bus : 10 %
# Accuracy of butterfly : 14 %
# Accuracy of camel : 12 %
# Accuracy of   can : 19 %
# Accuracy of castle : 41 %
# Accuracy of caterpillar : 16 %
# Accuracy of cattle : 11 %
# Accuracy of chair : 45 %
# Accuracy of chimpanzee : 40 %
# Accuracy of clock : 20 %
# Accuracy of cloud : 49 %
# Accuracy of cockroach : 46 %
# Accuracy of couch :  5 %
# Accuracy of   cra : 10 %
# Accuracy of crocodile : 11 %
# Accuracy of   cup : 38 %
# Accuracy of dinosaur :  9 %
# Accuracy of dolphin : 29 %
# Accuracy of elephant :  8 %
# Accuracy of flatfish : 13 %
# Accuracy of forest : 15 %
# Accuracy of   fox : 15 %
# Accuracy of  girl :  6 %
# Accuracy of hamster : 25 %
# Accuracy of house : 17 %
# Accuracy of kangaroo : 17 %
# Accuracy of keyboard : 17 %
# Accuracy of  lamp : 21 %
# Accuracy of lawn_mower : 48 %
# Accuracy of leopard : 11 %
# Accuracy of  lion : 26 %
# Accuracy of lizard : 13 %
# Accuracy of lobster :  8 %
# Accuracy of   man : 12 %
# Accuracy of maple_tree : 35 %
# Accuracy of motorcycle : 28 %
# Accuracy of mountain : 20 %
# Accuracy of mouse :  4 %
# Accuracy of mushroom : 16 %
# Accuracy of oak_tree : 47 %
# Accuracy of orange : 43 %
# Accuracy of orchid : 24 %
# Accuracy of otter :  6 %
# Accuracy of palm_tree : 30 %
# Accuracy of  pear : 22 %
# Accuracy of pickup_truck : 16 %
# Accuracy of pine_tree : 23 %
# Accuracy of plain : 66 %
# Accuracy of plate : 40 %
# Accuracy of poppy : 30 %
# Accuracy of porcupine : 20 %
# Accuracy of possum :  8 %
# Accuracy of rabbit : 12 %
# Accuracy of raccoon :  4 %
# Accuracy of   ray : 30 %
# Accuracy of  road : 56 %
# Accuracy of rocket : 33 %
# Accuracy of  rose : 27 %
# Accuracy of   sea : 44 %
# Accuracy of  seal :  7 %
# Accuracy of shark : 21 %
# Accuracy of shrew :  8 %
# Accuracy of skunk : 26 %
# Accuracy of skyscraper : 37 %
# Accuracy of snail :  9 %
# Accuracy of snake : 11 %
# Accuracy of spider :  6 %
# Accuracy of squirrel :  4 %
# Accuracy of streetcar : 16 %
# Accuracy of sunflower : 54 %
# Accuracy of sweet_pepper : 16 %
# Accuracy of table : 10 %
# Accuracy of  tank : 29 %
# Accuracy of telephone : 24 %
# Accuracy of television : 26 %
# Accuracy of tiger :  6 %
# Accuracy of tractor : 21 %
# Accuracy of train : 10 %
# Accuracy of trout : 32 %
# Accuracy of tulip : 16 %
# Accuracy of turtle : 11 %
# Accuracy of wardrobe : 39 %
# Accuracy of whale : 27 %
# Accuracy of willow_tree : 25 %
# Accuracy of  wolf : 12 %
# Accuracy of woman :  5 %
# Accuracy of  worm : 28 %
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test Accuracy</td><td>▁</td></tr><tr><td>Test Accuracy / Class</td><td>▆▂▃▃▂▂▂▅▆▃▁▂▄▂▁▂▃▃▁▄▁▅▁▂█▃▁▇▆▃▅▂▂▂▃▁▄▂▃▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test Accuracy</td><td>21.71</td></tr><tr><td>Test Accuracy / Class</td><td>28.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">experiment_2_test</strong> at: <a href='https://wandb.ai/1000kelvin/2LP%20-%20Hyperparameter%20Tuning/runs/wsd8818o' target="_blank">https://wandb.ai/1000kelvin/2LP%20-%20Hyperparameter%20Tuning/runs/wsd8818o</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231021_201449-wsd8818o/logs</code>

# %% [markdown]
# ## **2 more layers in TwolayerNet and ConvNet**

# %%
class FourLayerPerceptron(nn.Module):
    def __init__(self, input_dim, num_classes):
        super(FourLayerPerceptron, self).__init__()
        
        # First hidden layer
        self.fc1 = nn.Linear(input_dim, 512)
        
        # Second hidden layer (newly added)
        self.fc2 = nn.Linear(512, 256)
        self.bn2 = nn.BatchNorm1d(256)  # Batch Normalization after second layer
        
        # Output layer
        self.fc3 = nn.Linear(256, num_classes)
        
        
    def forward(self, x):
        x = x.view(x.size(0), -1)

        x = F.relu((self.fc1(x)))
        x = F.relu(self.bn2(self.fc2(x)))
        x = self.fc3(x)
        return x

# %%
import torch.nn as nn

class ConvNet2(nn.Module):
    def __init__(self, num_classes=100):
        super(ConvNet2, self).__init__()
        # First Convolutional Layer with 6 filters
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5, stride=1)
        self.act1 = nn.Tanh()
        self.pool1 = nn.AvgPool2d(kernel_size=2, stride=2)

        # Second Convolutional Layer with 16 filters
        self.conv2 = nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, stride=1)
        self.act2 = nn.Tanh()
        self.pool2 = nn.AvgPool2d(kernel_size=2, stride=2)

        # Dropout Layer
        self.dropout = nn.BatchNorm2d(16)

        # Fully Connected Layers
        self.fc1 = nn.Linear(in_features=16*5*5, out_features=120) # 5*5 from image dimension  
        self.act4 = nn.Tanh()
        self.fc2 = nn.Linear(in_features=120, out_features=100)
        self.act5 = nn.Tanh()
        self.fc3 = nn.Linear(in_features=100, out_features=84)
        self.act6 = nn.Tanh()
        self.fc4 = nn.Linear(in_features=84, out_features=num_classes)

    def forward(self, x):
        x = x.permute(0, 3, 1, 2)
        x = self.pool1(self.act1(self.conv1(x)))
        x = self.pool2(self.act2(self.conv2(x)))
        x = self.dropout(x)  # Applying Dropout
        x = x.view(-1, 16*5*5)
        x = self.act4(self.fc1(x))
        x = self.act5(self.fc2(x))
        x = self.act6(self.fc3(x))
        x = self.fc4(x)
        return x

# %%
#Initialize the network
flp = FourLayerPerceptron((3*32*32), 100)

# Train the network
wandb.init(
      # Set the project where this run will be logged
      project="4LP - Hyperparameter Tuning", 
      # We pass a run name (otherwise it’ll be randomly assigned, like sunshine-lollypop-10)
      name=f"experiment_{0}", 
      # Track hyperparameters and run metadata
      config={
      "Learning Rate": "1CycleLR - 1e-5 to 1e-4",
      "Architecture": "4LP",
      "Dataset": "CIFAR-100",
      "Epochs": 100,
      "Batch Size": 64,
      "Optimizer": "SGD with Momentum",
      "Weight Decay": 0.01,
      "Transformations": "True"
      })
train(flp, train_data_loader, print_epoch_stats=True, epochs=100, optimizer_name = "SGD", weight_decay = 0.001, lr=1e-4, clip_value=1)
wandb.finish()
# Out:
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/Users/joanvelja/Desktop/UvA AI/Computer Vision 1/Assignments/Lab5 Final/wandb/run-20231021_212416-0qe060wt</code>
# Syncing run <strong><a href='https://wandb.ai/1000kelvin/4LP%20-%20Hyperparameter%20Tuning/runs/0qe060wt' target="_blank">experiment_0</a></strong> to <a href='https://wandb.ai/1000kelvin/4LP%20-%20Hyperparameter%20Tuning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/1000kelvin/4LP%20-%20Hyperparameter%20Tuning' target="_blank">https://wandb.ai/1000kelvin/4LP%20-%20Hyperparameter%20Tuning</a>
#  View run at <a href='https://wandb.ai/1000kelvin/4LP%20-%20Hyperparameter%20Tuning/runs/0qe060wt' target="_blank">https://wandb.ai/1000kelvin/4LP%20-%20Hyperparameter%20Tuning/runs/0qe060wt</a>
# Training on mps
# Using CyclicLR
# Epoch 1 Summary: Loss: 4.444, Accuracy: 5.34%, lr: [4.2629714200602604e-05]
# Epoch 2 Summary: Loss: 4.243, Accuracy: 9.78%, lr: [5.049004264917373e-05]
# Epoch 3 Summary: Loss: 4.123, Accuracy: 11.69%, lr: [6.34948586067857e-05]
# Epoch 4 Summary: Loss: 4.024, Accuracy: 13.02%, lr: [8.150166645177212e-05]
# Epoch 5 Summary: Loss: 3.937, Accuracy: 14.27%, lr: [0.00010431316302456008]
# Epoch 6 Summary: Loss: 3.861, Accuracy: 15.60%, lr: [0.0001316793995065061]
# Epoch 7 Summary: Loss: 3.791, Accuracy: 16.69%, lr: [0.00016330052014471984]
# Epoch 8 Summary: Loss: 3.726, Accuracy: 17.65%, lr: [0.00019883004781427955]
# Epoch 9 Summary: Loss: 3.667, Accuracy: 18.48%, lr: [0.00023787868041746279]
# Epoch 10 Summary: Loss: 3.615, Accuracy: 19.19%, lr: [0.00028001855652230853]
# Epoch 11 Summary: Loss: 3.565, Accuracy: 20.12%, lr: [0.0003247879435012975]
# Epoch 12 Summary: Loss: 3.523, Accuracy: 20.75%, lr: [0.00037169629680155103]
# Epoch 13 Summary: Loss: 3.482, Accuracy: 21.36%, lr: [0.0004202296349114]
# Epoch 14 Summary: Loss: 3.445, Accuracy: 22.03%, lr: [0.0004698561711290524]
# Epoch 15 Summary: Loss: 3.410, Accuracy: 22.68%, lr: [0.0005200321404252652]
# Epoch 16 Summary: Loss: 3.381, Accuracy: 23.09%, lr: [0.0005702077575542583]
# Epoch 17 Summary: Loss: 3.353, Accuracy: 23.46%, lr: [0.000619833241128998]
# Epoch 18 Summary: Loss: 3.327, Accuracy: 24.15%, lr: [0.0006683648376541998]
# Epoch 19 Summary: Loss: 3.301, Accuracy: 24.56%, lr: [0.0007152707795108623]
# Epoch 20 Summary: Loss: 3.281, Accuracy: 24.79%, lr: [0.0007600371116098481]
# Epoch 21 Summary: Loss: 3.262, Accuracy: 25.12%, lr: [0.0008021733228710335]
# Epoch 86 Summary: Loss: 2.434, Accuracy: 44.53%, lr: [9.547825473845246e-05]
# Epoch 87 Summary: Loss: 2.403, Accuracy: 45.59%, lr: [8.270123472511686e-05]
# Epoch 88 Summary: Loss: 2.371, Accuracy: 46.65%, lr: [7.076460291756155e-05]
# Epoch 89 Summary: Loss: 2.343, Accuracy: 47.32%, lr: [5.969239810368918e-05]
# Epoch 90 Summary: Loss: 2.307, Accuracy: 48.40%, lr: [4.950691823047621e-05]
# Epoch 91 Summary: Loss: 2.275, Accuracy: 49.65%, lr: [4.022867549887718e-05]
# Epoch 92 Summary: Loss: 2.244, Accuracy: 50.68%, lr: [3.187635505498053e-05]
# Epoch 93 Summary: Loss: 2.217, Accuracy: 51.67%, lr: [2.446677736061147e-05]
# Epoch 94 Summary: Loss: 2.189, Accuracy: 52.46%, lr: [1.801486431916034e-05]
# Epoch 95 Summary: Loss: 2.166, Accuracy: 53.37%, lr: [1.253360922485522e-05]
# Epoch 96 Summary: Loss: 2.146, Accuracy: 54.08%, lr: [8.034050595996071e-06]
# Epoch 97 Summary: Loss: 2.129, Accuracy: 54.62%, lr: [4.525249944848247e-06]
# Epoch 98 Summary: Loss: 2.117, Accuracy: 54.88%, lr: [2.0142735289629757e-06]
# Epoch 99 Summary: Loss: 2.108, Accuracy: 55.42%, lr: [5.061781206742738e-07]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/joanvelja/Desktop/UvA AI/Computer Vision 1/Assignments/Lab5 Final/CV1 Final Lab Pt2 (V2).ipynb Cella 64 line 2
#       <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y153sZmlsZQ%3D%3D?line=3'>4</a> # Train the network
#       <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y153sZmlsZQ%3D%3D?line=4'>5</a> wandb.init(
#       <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y153sZmlsZQ%3D%3D?line=5'>6</a>       # Set the project where this run will be logged
#       <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y153sZmlsZQ%3D%3D?line=6'>7</a>       project="4LP - Hyperparameter Tuning",
#    (...)
#      <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y153sZmlsZQ%3D%3D?line=18'>19</a>       "Transformations": "True"
#      <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y153sZmlsZQ%3D%3D?line=19'>20</a>       })
# ---> <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y153sZmlsZQ%3D%3D?line=20'>21</a> train(flp, train_data_loader, print_epoch_stats=True, epochs=100, optimizer_name = "SGD", weight_decay = 0.01, lr=1e-4, clip_value=1)
#      <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y153sZmlsZQ%3D%3D?line=21'>22</a> wandb.finish()
#
# /Users/joanvelja/Desktop/UvA AI/Computer Vision 1/Assignments/Lab5 Final/CV1 Final Lab Pt2 (V2).ipynb Cella 64 line 5
#      <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y153sZmlsZQ%3D%3D?line=47'>48</a> optimizer.zero_grad()
#      <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y153sZmlsZQ%3D%3D?line=49'>50</a> # forward + backward + optimize
# ---> <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y153sZmlsZQ%3D%3D?line=50'>51</a> outputs = net(inputs)
#      <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y153sZmlsZQ%3D%3D?line=51'>52</a> loss = criterion(outputs, labels)
#      <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y153sZmlsZQ%3D%3D?line=52'>53</a> loss.backward()
#
# File ~/anaconda3/envs/cv1_torch/lib/python3.11/site-packages/torch/nn/modules/module.py:1519, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1517     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1518 else:
# -> 1519     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/cv1_torch/lib/python3.11/site-packages/torch/nn/modules/module.py:1528, in Module._call_impl(self, *args, **kwargs)
#    1523 # If we don't have any hooks, we want to skip the rest of the logic in
#    1524 # this function, and just call forward.
#    1525 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1526         or _global_backward_pre_hooks or _global_backward_hooks
#    1527         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1528     return forward_call(*args, **kwargs)
#    1530 try:
#    1531     result = None
#
# /Users/joanvelja/Desktop/UvA AI/Computer Vision 1/Assignments/Lab5 Final/CV1 Final Lab Pt2 (V2).ipynb Cella 64 line 2
#      <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y153sZmlsZQ%3D%3D?line=16'>17</a> x = x.view(x.size(0), -1)
#      <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y153sZmlsZQ%3D%3D?line=18'>19</a> x = F.relu((self.fc1(x)))
# ---> <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y153sZmlsZQ%3D%3D?line=19'>20</a> x = F.relu(self.bn2(self.fc2(x)))
#      <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y153sZmlsZQ%3D%3D?line=20'>21</a> x = self.fc3(x)
#      <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y153sZmlsZQ%3D%3D?line=21'>22</a> return x
#
# File ~/anaconda3/envs/cv1_torch/lib/python3.11/site-packages/torch/nn/modules/module.py:1519, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1517     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1518 else:
# -> 1519     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/cv1_torch/lib/python3.11/site-packages/torch/nn/modules/module.py:1528, in Module._call_impl(self, *args, **kwargs)
#    1523 # If we don't have any hooks, we want to skip the rest of the logic in
#    1524 # this function, and just call forward.
#    1525 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1526         or _global_backward_pre_hooks or _global_backward_hooks
#    1527         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1528     return forward_call(*args, **kwargs)
#    1530 try:
#    1531     result = None
#
# File ~/anaconda3/envs/cv1_torch/lib/python3.11/site-packages/torch/nn/modules/batchnorm.py:151, in _BatchNorm.forward(self, input)
#     148 if self.training and self.track_running_stats:
#     149     # TODO: if statement only here to tell the jit to skip emitting this when it is None
#     150     if self.num_batches_tracked is not None:  # type: ignore[has-type]
# --> 151         self.num_batches_tracked.add_(1)  # type: ignore[has-type]
#     152         if self.momentum is None:  # use cumulative moving average
#     153             exponential_average_factor = 1.0 / float(self.num_batches_tracked)
#
# KeyboardInterrupt:

# %%
wandb.init(
      # Set the project where this run will be logged
      project="4LP - Hyperparameter Tuning", 
      # We pass a run name (otherwise it’ll be randomly assigned, like sunshine-lollypop-10)
      name=f"experiment_{3}_test", 
      # Track hyperparameters and run metadata
      config={
      "Learning Rate": "1CycleLR - lr=5e-4 to 5e-3", 
      "Architecture": "4LP",
      "Dataset": "CIFAR-100",
      "Epochs": 1,
      "Batch Size": 64,
      "Optimizer": "SGD with Momentum",
      "Weight Decay": 0.01,
      "Transformations": "True",
      "Test": "True"
      })
      
valid(flp, test_data_loader)
wandb.log({"Test Accuracy": valid(flp, test_data_loader)})

class_correct, class_total = valid_class(flp, test_data_loader, classes)

for i in range(len(classes)):
        print('Accuracy of %5s : %2d %%' % (
            classes[i], 100 * class_correct[i] / class_total[i]))
        wandb.log({"Test Accuracy / Class": 100 * class_correct[i] / class_total[i]})

wandb.finish()
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011144720833342742, max=1.0…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/Users/joanvelja/Desktop/UvA AI/Computer Vision 1/Assignments/Lab5 Final/wandb/run-20231021_202322-mul7zvx4</code>
# Syncing run <strong><a href='https://wandb.ai/1000kelvin/4LP%20-%20Hyperparameter%20Tuning/runs/mul7zvx4' target="_blank">experiment_3_test</a></strong> to <a href='https://wandb.ai/1000kelvin/4LP%20-%20Hyperparameter%20Tuning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/1000kelvin/4LP%20-%20Hyperparameter%20Tuning' target="_blank">https://wandb.ai/1000kelvin/4LP%20-%20Hyperparameter%20Tuning</a>
#  View run at <a href='https://wandb.ai/1000kelvin/4LP%20-%20Hyperparameter%20Tuning/runs/mul7zvx4' target="_blank">https://wandb.ai/1000kelvin/4LP%20-%20Hyperparameter%20Tuning/runs/mul7zvx4</a>
# Accuracy of the network on the 10000 test images: 26 %
# Accuracy of the network on the 10000 test images: 26 %
# Accuracy of apple : 55 %
# Accuracy of aquarium_fish : 39 %
# Accuracy of  baby : 17 %
# Accuracy of  bear : 12 %
# Accuracy of beaver : 16 %
# Accuracy of   bed : 31 %
# Accuracy of   bee : 22 %
# Accuracy of beetle : 26 %
# Accuracy of bicycle : 25 %
# Accuracy of bottle : 38 %
# Accuracy of  bowl : 22 %
# Accuracy of   boy : 20 %
# Accuracy of bridge : 27 %
# Accuracy of   bus : 10 %
# Accuracy of butterfly : 14 %
# Accuracy of camel : 16 %
# Accuracy of   can : 31 %
# Accuracy of castle : 38 %
# Accuracy of caterpillar : 10 %
# Accuracy of cattle : 14 %
# Accuracy of chair : 54 %
# Accuracy of chimpanzee : 32 %
# Accuracy of clock : 24 %
# Accuracy of cloud : 56 %
# Accuracy of cockroach : 54 %
# Accuracy of couch : 14 %
# Accuracy of   cra : 20 %
# Accuracy of crocodile : 15 %
# Accuracy of   cup : 46 %
# Accuracy of dinosaur : 20 %
# Accuracy of dolphin : 37 %
# Accuracy of elephant : 18 %
# Accuracy of flatfish : 25 %
# Accuracy of forest : 22 %
# Accuracy of   fox : 23 %
# Accuracy of  girl : 14 %
# Accuracy of hamster : 23 %
# Accuracy of house : 17 %
# Accuracy of kangaroo : 16 %
# Accuracy of keyboard : 27 %
# Accuracy of  lamp : 27 %
# Accuracy of lawn_mower : 50 %
# Accuracy of leopard : 13 %
# Accuracy of  lion : 22 %
# Accuracy of lizard : 11 %
# Accuracy of lobster : 15 %
# Accuracy of   man : 10 %
# Accuracy of maple_tree : 37 %
# Accuracy of motorcycle : 31 %
# Accuracy of mountain : 35 %
# Accuracy of mouse : 11 %
# Accuracy of mushroom : 19 %
# Accuracy of oak_tree : 55 %
# Accuracy of orange : 52 %
# Accuracy of orchid : 28 %
# Accuracy of otter :  4 %
# Accuracy of palm_tree : 26 %
# Accuracy of  pear : 26 %
# Accuracy of pickup_truck : 30 %
# Accuracy of pine_tree : 23 %
# Accuracy of plain : 75 %
# Accuracy of plate : 47 %
# Accuracy of poppy : 38 %
# Accuracy of porcupine : 31 %
# Accuracy of possum : 13 %
# Accuracy of rabbit : 12 %
# Accuracy of raccoon :  6 %
# Accuracy of   ray : 36 %
# Accuracy of  road : 59 %
# Accuracy of rocket : 44 %
# Accuracy of  rose : 31 %
# Accuracy of   sea : 49 %
# Accuracy of  seal :  5 %
# Accuracy of shark : 28 %
# Accuracy of shrew : 15 %
# Accuracy of skunk : 38 %
# Accuracy of skyscraper : 53 %
# Accuracy of snail :  8 %
# Accuracy of snake :  7 %
# Accuracy of spider : 22 %
# Accuracy of squirrel :  9 %
# Accuracy of streetcar : 10 %
# Accuracy of sunflower : 49 %
# Accuracy of sweet_pepper : 22 %
# Accuracy of table : 13 %
# Accuracy of  tank : 39 %
# Accuracy of telephone : 31 %
# Accuracy of television : 22 %
# Accuracy of tiger : 14 %
# Accuracy of tractor : 21 %
# Accuracy of train : 22 %
# Accuracy of trout : 34 %
# Accuracy of tulip : 13 %
# Accuracy of turtle : 13 %
# Accuracy of wardrobe : 51 %
# Accuracy of whale : 39 %
# Accuracy of willow_tree : 22 %
# Accuracy of  wolf : 18 %
# Accuracy of woman : 14 %
# Accuracy of  worm : 25 %
# Accuracy of apple : 55 %
# Accuracy of aquarium_fish : 39 %
# Accuracy of  baby : 17 %
# Accuracy of  bear : 12 %
# Accuracy of beaver : 16 %
# Accuracy of   bed : 31 %
# Accuracy of   bee : 22 %
# Accuracy of beetle : 26 %
# Accuracy of bicycle : 25 %
# Accuracy of bottle : 38 %
# Accuracy of  bowl : 22 %
# Accuracy of   boy : 20 %
# Accuracy of bridge : 27 %
# Accuracy of   bus : 10 %
# Accuracy of butterfly : 14 %
# Accuracy of camel : 16 %
# Accuracy of   can : 31 %
# Accuracy of castle : 38 %
# Accuracy of caterpillar : 10 %
# Accuracy of cattle : 14 %
# Accuracy of chair : 54 %
# Accuracy of chimpanzee : 32 %
# Accuracy of clock : 24 %
# Accuracy of cloud : 56 %
# Accuracy of cockroach : 54 %
# Accuracy of couch : 14 %
# Accuracy of   cra : 20 %
# Accuracy of crocodile : 15 %
# Accuracy of   cup : 46 %
# Accuracy of dinosaur : 20 %
# Accuracy of dolphin : 37 %
# Accuracy of elephant : 18 %
# Accuracy of flatfish : 25 %
# Accuracy of forest : 22 %
# Accuracy of   fox : 23 %
# Accuracy of  girl : 14 %
# Accuracy of hamster : 23 %
# Accuracy of house : 17 %
# Accuracy of kangaroo : 16 %
# Accuracy of keyboard : 27 %
# Accuracy of  lamp : 27 %
# Accuracy of lawn_mower : 50 %
# Accuracy of leopard : 13 %
# Accuracy of  lion : 22 %
# Accuracy of lizard : 11 %
# Accuracy of lobster : 15 %
# Accuracy of   man : 10 %
# Accuracy of maple_tree : 37 %
# Accuracy of motorcycle : 31 %
# Accuracy of mountain : 35 %
# Accuracy of mouse : 11 %
# Accuracy of mushroom : 19 %
# Accuracy of oak_tree : 55 %
# Accuracy of orange : 52 %
# Accuracy of orchid : 28 %
# Accuracy of otter :  4 %
# Accuracy of palm_tree : 26 %
# Accuracy of  pear : 26 %
# Accuracy of pickup_truck : 30 %
# Accuracy of pine_tree : 23 %
# Accuracy of plain : 75 %
# Accuracy of plate : 47 %
# Accuracy of poppy : 38 %
# Accuracy of porcupine : 31 %
# Accuracy of possum : 13 %
# Accuracy of rabbit : 12 %
# Accuracy of raccoon :  6 %
# Accuracy of   ray : 36 %
# Accuracy of  road : 59 %
# Accuracy of rocket : 44 %
# Accuracy of  rose : 31 %
# Accuracy of   sea : 49 %
# Accuracy of  seal :  5 %
# Accuracy of shark : 28 %
# Accuracy of shrew : 15 %
# Accuracy of skunk : 38 %
# Accuracy of skyscraper : 53 %
# Accuracy of snail :  8 %
# Accuracy of snake :  7 %
# Accuracy of spider : 22 %
# Accuracy of squirrel :  9 %
# Accuracy of streetcar : 10 %
# Accuracy of sunflower : 49 %
# Accuracy of sweet_pepper : 22 %
# Accuracy of table : 13 %
# Accuracy of  tank : 39 %
# Accuracy of telephone : 31 %
# Accuracy of television : 22 %
# Accuracy of tiger : 14 %
# Accuracy of tractor : 21 %
# Accuracy of train : 22 %
# Accuracy of trout : 34 %
# Accuracy of tulip : 13 %
# Accuracy of turtle : 13 %
# Accuracy of wardrobe : 51 %
# Accuracy of whale : 39 %
# Accuracy of willow_tree : 22 %
# Accuracy of  wolf : 18 %
# Accuracy of woman : 14 %
# Accuracy of  worm : 25 %
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test Accuracy</td><td>▁</td></tr><tr><td>Test Accuracy / Class</td><td>▆▂▄▃▃▃▂▄▆▃▂▂▄▃▂▂▃▃▂▄▂▆▁▄█▄▁▆▅▃▆▁▂▃▄▂▄▂▃▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test Accuracy</td><td>26.63</td></tr><tr><td>Test Accuracy / Class</td><td>25.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">experiment_3_test</strong> at: <a href='https://wandb.ai/1000kelvin/4LP%20-%20Hyperparameter%20Tuning/runs/mul7zvx4' target="_blank">https://wandb.ai/1000kelvin/4LP%20-%20Hyperparameter%20Tuning/runs/mul7zvx4</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231021_202322-mul7zvx4/logs</code>

# %%
#Initialize the network
convnet2 = ConvNet2()

# Train the network
wandb.init(
      # Set the project where this run will be logged
      project="ConvNet2 - Hyperparameter Tuning", 
      # We pass a run name (otherwise it’ll be randomly assigned, like sunshine-lollypop-10)
      name=f"experiment_{6}", 
      # Track hyperparameters and run metadata
      config={
      "Learning Rate": "1CycleLR - 8e-4 to 8e-3",
      "Architecture": "ConvNet2",
      "Dataset": "CIFAR-100",
      "Epochs": 100,
      "Batch Size": 64,
      "Optimizer": "SGD with Momentum",
      "Weight Decay": 0.01,
      "Transformations": "True"
      })
train(convnet2, train_data_loader, print_epoch_stats=True, epochs=100, optimizer_name = "SGD", weight_decay = 0.001, lr=5e-5, clip_value=1)
wandb.finish()
# Out:
# Finishing last run (ID:xx4tniug) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test Accuracy</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test Accuracy</td><td>36.825</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">experiment_1_test</strong> at: <a href='https://wandb.ai/1000kelvin/TransferLearning/runs/xx4tniug' target="_blank">https://wandb.ai/1000kelvin/TransferLearning/runs/xx4tniug</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231021_231005-xx4tniug/logs</code>
# Successfully finished last run (ID:xx4tniug). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011167394444459609, max=1.0…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/Users/joanvelja/Desktop/UvA AI/Computer Vision 1/Assignments/Lab5 Final/wandb/run-20231021_232155-zx64avhd</code>
# Syncing run <strong><a href='https://wandb.ai/1000kelvin/ConvNet2%20-%20Hyperparameter%20Tuning/runs/zx64avhd' target="_blank">experiment_6</a></strong> to <a href='https://wandb.ai/1000kelvin/ConvNet2%20-%20Hyperparameter%20Tuning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/1000kelvin/ConvNet2%20-%20Hyperparameter%20Tuning' target="_blank">https://wandb.ai/1000kelvin/ConvNet2%20-%20Hyperparameter%20Tuning</a>
#  View run at <a href='https://wandb.ai/1000kelvin/ConvNet2%20-%20Hyperparameter%20Tuning/runs/zx64avhd' target="_blank">https://wandb.ai/1000kelvin/ConvNet2%20-%20Hyperparameter%20Tuning/runs/zx64avhd</a>
# Training on mps
# Using CyclicLR
# Epoch 1 Summary: Loss: 4.594, Accuracy: 1.55%, lr: [0.0002131485710030129]
# Epoch 2 Summary: Loss: 4.529, Accuracy: 3.07%, lr: [0.00025245021324586843]
# Epoch 3 Summary: Loss: 4.441, Accuracy: 3.68%, lr: [0.0003174742930339286]
# Epoch 4 Summary: Loss: 4.358, Accuracy: 4.15%, lr: [0.0004075083322588602]
# Epoch 5 Summary: Loss: 4.280, Accuracy: 5.07%, lr: [0.0005215658151227999]
# Epoch 6 Summary: Loss: 4.193, Accuracy: 6.33%, lr: [0.00065839699753253]
# Epoch 7 Summary: Loss: 4.110, Accuracy: 7.28%, lr: [0.0008165026007235987]
# Epoch 8 Summary: Loss: 4.021, Accuracy: 8.47%, lr: [0.0009941502390713973]
# Epoch 9 Summary: Loss: 3.917, Accuracy: 10.09%, lr: [0.0011893934020873135]
# Epoch 10 Summary: Loss: 3.828, Accuracy: 11.49%, lr: [0.0014000927826115423]
# Epoch 11 Summary: Loss: 3.761, Accuracy: 12.31%, lr: [0.001623939717506487]
# Epoch 12 Summary: Loss: 3.693, Accuracy: 13.50%, lr: [0.0018584814840077548]
# Epoch 13 Summary: Loss: 3.661, Accuracy: 14.21%, lr: [0.0021011481745569997]
# Epoch 14 Summary: Loss: 3.601, Accuracy: 15.23%, lr: [0.0023492808556452617]
# Epoch 15 Summary: Loss: 3.509, Accuracy: 16.81%, lr: [0.0026001607021263256]
# Epoch 16 Summary: Loss: 3.460, Accuracy: 17.66%, lr: [0.002851038787771292]
# Epoch 17 Summary: Loss: 3.406, Accuracy: 18.55%, lr: [0.0030991662056449897]
# Epoch 18 Summary: Loss: 3.364, Accuracy: 19.35%, lr: [0.0033418241882709984]
# Epoch 19 Summary: Loss: 3.312, Accuracy: 20.31%, lr: [0.0035763538975543113]
# Epoch 20 Summary: Loss: 3.267, Accuracy: 21.17%, lr: [0.0038001855580492407]
# Epoch 21 Summary: Loss: 3.221, Accuracy: 22.01%, lr: [0.0040108666143551675]
# Epoch 22 Summary: Loss: 3.182, Accuracy: 22.44%, lr: [0.004206088604115569]
# Epoch 23 Summary: Loss: 3.143, Accuracy: 23.34%, lr: [0.00438371245216902]
# Epoch 24 Summary: Loss: 3.127, Accuracy: 23.54%, lr: [0.004541791908700549]
# Epoch 90 Summary: Loss: 2.083, Accuracy: 45.40%, lr: [0.00024753459115238105]
# Epoch 91 Summary: Loss: 2.067, Accuracy: 45.60%, lr: [0.0002011433774943859]
# Epoch 92 Summary: Loss: 2.049, Accuracy: 46.27%, lr: [0.00015938177527490262]
# Epoch 93 Summary: Loss: 2.039, Accuracy: 46.45%, lr: [0.00012233388680305736]
# Epoch 94 Summary: Loss: 2.025, Accuracy: 46.79%, lr: [9.007432159580172e-05]
# Epoch 95 Summary: Loss: 2.013, Accuracy: 47.46%, lr: [6.26680461242761e-05]
# Epoch 96 Summary: Loss: 2.003, Accuracy: 47.52%, lr: [4.017025297998036e-05]
# Epoch 97 Summary: Loss: 1.998, Accuracy: 47.68%, lr: [2.2626249724241235e-05]
# Epoch 98 Summary: Loss: 1.993, Accuracy: 47.73%, lr: [1.007136764481488e-05]
# Epoch 99 Summary: Loss: 1.987, Accuracy: 48.09%, lr: [2.530890603371369e-06]
# Epoch 100 Summary: Loss: 1.985, Accuracy: 48.03%, lr: [2.00041171665147e-08]
# Finished Training
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.003 MB of 0.019 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.172106…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>Learning Rate</td><td>▁▁▂▂▃▄▅▆▇▇███████▇▇▇▇▆▆▅▅▅▄▄▃▃▃▂▂▂▂▁▁▁▁▁</td></tr><tr><td>Training Accuracy</td><td>▁▁▂▂▃▃▃▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇█████</td></tr><tr><td>Training Loss</td><td>██▇▆▆▅▅▅▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>Training Loss / Step</td><td>██▇▇▆▅▆▅▅▄▄▄▄▃▅▄▄▃▃▃▃▄▄▂▃▃▂▃▄▂▂▂▂▃▁▂▂▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Epoch</td><td>100</td></tr><tr><td>Learning Rate</td><td>0.0</td></tr><tr><td>Training Accuracy</td><td>48.034</td></tr><tr><td>Training Loss</td><td>1.98455</td></tr><tr><td>Training Loss / Step</td><td>2.2938</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">experiment_6</strong> at: <a href='https://wandb.ai/1000kelvin/ConvNet2%20-%20Hyperparameter%20Tuning/runs/zx64avhd' target="_blank">https://wandb.ai/1000kelvin/ConvNet2%20-%20Hyperparameter%20Tuning/runs/zx64avhd</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231021_232155-zx64avhd/logs</code>

# %%
wandb.init(
      # Set the project where this run will be logged
      project="ConvNet2 - Hyperparameter Tuning", 
      # We pass a run name (otherwise it’ll be randomly assigned, like sunshine-lollypop-10)
      name=f"experiment_{6}_test", 
      # Track hyperparameters and run metadata
      config={
      "Learning Rate": "1CycleLR - lr=5e-4 to 5e-3", 
      "Architecture": "ConvNet2",
      "Dataset": "CIFAR-100",
      "Epochs": 1,
      "Batch Size": 64,
      "Optimizer": "SGD with Momentum",
      "Weight Decay": 0.01,
      "Transformations": "True",
      "Test": "True"
      })
      
valid(convnet2, test_data_loader)
wandb.log({"Test Accuracy": valid(convnet2, test_data_loader)})

class_correct, class_total = valid_class(convnet2, test_data_loader, classes)

for i in range(len(classes)):
        print('Accuracy of %5s : %2d %%' % (
            classes[i], 100 * class_correct[i] / class_total[i]))
        wandb.log({"Test Accuracy / Class": 100 * class_correct[i] / class_total[i]})

wandb.finish()
# Out:
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/Users/joanvelja/Desktop/UvA AI/Computer Vision 1/Assignments/Lab5 Final/wandb/run-20231021_233830-ra4ek2vr</code>
# Syncing run <strong><a href='https://wandb.ai/1000kelvin/ConvNet2%20-%20Hyperparameter%20Tuning/runs/ra4ek2vr' target="_blank">experiment_6_test</a></strong> to <a href='https://wandb.ai/1000kelvin/ConvNet2%20-%20Hyperparameter%20Tuning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/1000kelvin/ConvNet2%20-%20Hyperparameter%20Tuning' target="_blank">https://wandb.ai/1000kelvin/ConvNet2%20-%20Hyperparameter%20Tuning</a>
#  View run at <a href='https://wandb.ai/1000kelvin/ConvNet2%20-%20Hyperparameter%20Tuning/runs/ra4ek2vr' target="_blank">https://wandb.ai/1000kelvin/ConvNet2%20-%20Hyperparameter%20Tuning/runs/ra4ek2vr</a>
# Accuracy of the network on the 10000 test images: 26 %
# Accuracy of the network on the 10000 test images: 26 %
# Accuracy of apple : 57 %
# Accuracy of aquarium_fish : 34 %
# Accuracy of  baby : 16 %
# Accuracy of  bear : 15 %
# Accuracy of beaver : 11 %
# Accuracy of   bed : 28 %
# Accuracy of   bee : 20 %
# Accuracy of beetle : 30 %
# Accuracy of bicycle : 37 %
# Accuracy of bottle : 44 %
# Accuracy of  bowl : 14 %
# Accuracy of   boy : 10 %
# Accuracy of bridge : 31 %
# Accuracy of   bus : 24 %
# Accuracy of butterfly : 14 %
# Accuracy of camel : 17 %
# Accuracy of   can : 27 %
# Accuracy of castle : 48 %
# Accuracy of caterpillar : 23 %
# Accuracy of cattle : 15 %
# Accuracy of chair : 56 %
# Accuracy of chimpanzee : 33 %
# Accuracy of clock : 20 %
# Accuracy of cloud : 43 %
# Accuracy of cockroach : 54 %
# Accuracy of couch : 12 %
# Accuracy of   cra : 14 %
# Accuracy of crocodile : 16 %
# Accuracy of   cup : 34 %
# Accuracy of dinosaur : 24 %
# Accuracy of dolphin : 34 %
# Accuracy of elephant : 22 %
# Accuracy of flatfish : 25 %
# Accuracy of forest : 22 %
# Accuracy of   fox : 18 %
# Accuracy of  girl :  9 %
# Accuracy of hamster : 24 %
# Accuracy of house : 16 %
# Accuracy of kangaroo :  7 %
# Accuracy of keyboard : 35 %
# Accuracy of  lamp : 20 %
# Accuracy of lawn_mower : 51 %
# Accuracy of leopard : 18 %
# Accuracy of  lion : 22 %
# Accuracy of lizard : 17 %
# Accuracy of lobster :  9 %
# Accuracy of   man : 22 %
# Accuracy of maple_tree : 28 %
# Accuracy of motorcycle : 45 %
# Accuracy of mountain : 27 %
# Accuracy of mouse :  5 %
# Accuracy of mushroom : 15 %
# Accuracy of oak_tree : 62 %
# Accuracy of orange : 46 %
# Accuracy of orchid : 36 %
# Accuracy of otter :  7 %
# Accuracy of palm_tree : 36 %
# Accuracy of  pear : 30 %
# Accuracy of pickup_truck : 23 %
# Accuracy of pine_tree : 22 %
# Accuracy of plain : 61 %
# Accuracy of plate : 40 %
# Accuracy of poppy : 35 %
# Accuracy of porcupine : 20 %
# Accuracy of possum :  7 %
# Accuracy of rabbit :  9 %
# Accuracy of raccoon : 10 %
# Accuracy of   ray : 20 %
# Accuracy of  road : 60 %
# Accuracy of rocket : 41 %
# Accuracy of  rose : 27 %
# Accuracy of   sea : 46 %
# Accuracy of  seal :  6 %
# Accuracy of shark : 31 %
# Accuracy of shrew : 15 %
# Accuracy of skunk : 35 %
# Accuracy of skyscraper : 53 %
# Accuracy of snail : 10 %
# Accuracy of snake :  8 %
# Accuracy of spider : 14 %
# Accuracy of squirrel :  4 %
# Accuracy of streetcar : 16 %
# Accuracy of sunflower : 52 %
# Accuracy of sweet_pepper : 15 %
# Accuracy of table : 13 %
# Accuracy of  tank : 43 %
# Accuracy of telephone : 32 %
# Accuracy of television : 33 %
# Accuracy of tiger : 17 %
# Accuracy of tractor : 29 %
# Accuracy of train : 23 %
# Accuracy of trout : 38 %
# Accuracy of tulip :  9 %
# Accuracy of turtle : 12 %
# Accuracy of wardrobe : 61 %
# Accuracy of whale : 35 %
# Accuracy of willow_tree : 23 %
# Accuracy of  wolf : 15 %
# Accuracy of woman :  8 %
# Accuracy of  worm : 10 %
# Accuracy of apple : 57 %
# Accuracy of aquarium_fish : 34 %
# Accuracy of  baby : 16 %
# Accuracy of  bear : 15 %
# Accuracy of beaver : 11 %
# Accuracy of   bed : 28 %
# Accuracy of   bee : 20 %
# Accuracy of beetle : 30 %
# Accuracy of bicycle : 37 %
# Accuracy of bottle : 44 %
# Accuracy of  bowl : 14 %
# Accuracy of   boy : 10 %
# Accuracy of bridge : 31 %
# Accuracy of   bus : 24 %
# Accuracy of butterfly : 14 %
# Accuracy of camel : 17 %
# Accuracy of   can : 27 %
# Accuracy of castle : 48 %
# Accuracy of caterpillar : 23 %
# Accuracy of cattle : 15 %
# Accuracy of chair : 56 %
# Accuracy of chimpanzee : 33 %
# Accuracy of clock : 20 %
# Accuracy of cloud : 43 %
# Accuracy of cockroach : 54 %
# Accuracy of couch : 12 %
# Accuracy of   cra : 14 %
# Accuracy of crocodile : 16 %
# Accuracy of   cup : 34 %
# Accuracy of dinosaur : 24 %
# Accuracy of dolphin : 34 %
# Accuracy of elephant : 22 %
# Accuracy of flatfish : 25 %
# Accuracy of forest : 22 %
# Accuracy of   fox : 18 %
# Accuracy of  girl :  9 %
# Accuracy of hamster : 24 %
# Accuracy of house : 16 %
# Accuracy of kangaroo :  7 %
# Accuracy of keyboard : 35 %
# Accuracy of  lamp : 20 %
# Accuracy of lawn_mower : 51 %
# Accuracy of leopard : 18 %
# Accuracy of  lion : 22 %
# Accuracy of lizard : 17 %
# Accuracy of lobster :  9 %
# Accuracy of   man : 22 %
# Accuracy of maple_tree : 28 %
# Accuracy of motorcycle : 45 %
# Accuracy of mountain : 27 %
# Accuracy of mouse :  5 %
# Accuracy of mushroom : 15 %
# Accuracy of oak_tree : 62 %
# Accuracy of orange : 46 %
# Accuracy of orchid : 36 %
# Accuracy of otter :  7 %
# Accuracy of palm_tree : 36 %
# Accuracy of  pear : 30 %
# Accuracy of pickup_truck : 23 %
# Accuracy of pine_tree : 22 %
# Accuracy of plain : 61 %
# Accuracy of plate : 40 %
# Accuracy of poppy : 35 %
# Accuracy of porcupine : 20 %
# Accuracy of possum :  7 %
# Accuracy of rabbit :  9 %
# Accuracy of raccoon : 10 %
# Accuracy of   ray : 20 %
# Accuracy of  road : 60 %
# Accuracy of rocket : 41 %
# Accuracy of  rose : 27 %
# Accuracy of   sea : 46 %
# Accuracy of  seal :  6 %
# Accuracy of shark : 31 %
# Accuracy of shrew : 15 %
# Accuracy of skunk : 35 %
# Accuracy of skyscraper : 53 %
# Accuracy of snail : 10 %
# Accuracy of snake :  8 %
# Accuracy of spider : 14 %
# Accuracy of squirrel :  4 %
# Accuracy of streetcar : 16 %
# Accuracy of sunflower : 52 %
# Accuracy of sweet_pepper : 15 %
# Accuracy of table : 13 %
# Accuracy of  tank : 43 %
# Accuracy of telephone : 32 %
# Accuracy of television : 33 %
# Accuracy of tiger : 17 %
# Accuracy of tractor : 29 %
# Accuracy of train : 23 %
# Accuracy of trout : 38 %
# Accuracy of tulip :  9 %
# Accuracy of turtle : 12 %
# Accuracy of wardrobe : 61 %
# Accuracy of whale : 35 %
# Accuracy of willow_tree : 23 %
# Accuracy of  wolf : 15 %
# Accuracy of woman :  8 %
# Accuracy of  worm : 10 %
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test Accuracy</td><td>▁</td></tr><tr><td>Test Accuracy / Class</td><td>▇▂▄▄▂▄▃▆▇▃▂▂▅▃▁▁▃▃▁▆▁▆▁▃█▃▂█▆▄▇▁▂▂▄▃▅▂▃▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test Accuracy</td><td>26.1</td></tr><tr><td>Test Accuracy / Class</td><td>10.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">experiment_6_test</strong> at: <a href='https://wandb.ai/1000kelvin/ConvNet2%20-%20Hyperparameter%20Tuning/runs/ra4ek2vr' target="_blank">https://wandb.ai/1000kelvin/ConvNet2%20-%20Hyperparameter%20Tuning/runs/ra4ek2vr</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231021_233830-ra4ek2vr/logs</code>

# %%
torch.save(convnet.state_dict(), "convnet_CIFAR100.pth")

# %%
compare_classifiers(flp, convnet2, test_data_loader, classes)
# Out:
# Accuracy of apple : 56 %
# Accuracy of aquarium_fish : 44 %
# Accuracy of  baby : 18 %
# Accuracy of  bear : 14 %
# Accuracy of beaver :  3 %
# Accuracy of   bed : 29 %
# Accuracy of   bee : 21 %
# Accuracy of beetle : 28 %
# Accuracy of bicycle : 28 %
# Accuracy of bottle : 38 %
# Accuracy of  bowl : 15 %
# Accuracy of   boy : 19 %
# Accuracy of bridge : 21 %
# Accuracy of   bus : 18 %
# Accuracy of butterfly : 12 %
# Accuracy of camel : 13 %
# Accuracy of   can : 21 %
# Accuracy of castle : 47 %
# Accuracy of caterpillar : 21 %
# Accuracy of cattle : 20 %
# Accuracy of chair : 62 %
# Accuracy of chimpanzee : 47 %
# Accuracy of clock : 18 %
# Accuracy of cloud : 51 %
# Accuracy of cockroach : 55 %
# Accuracy of couch : 13 %
# Accuracy of   cra :  7 %
# Accuracy of crocodile : 12 %
# Accuracy of   cup : 48 %
# Accuracy of dinosaur : 22 %
# Accuracy of dolphin : 30 %
# Accuracy of elephant : 19 %
# Accuracy of flatfish : 19 %
# Accuracy of forest : 33 %
# Accuracy of   fox : 23 %
# Accuracy of  girl : 10 %
# Accuracy of hamster : 31 %
# Accuracy of house : 20 %
# Accuracy of kangaroo : 13 %
# Accuracy of keyboard : 25 %
# Accuracy of  lamp : 29 %
# Accuracy of lawn_mower : 53 %
# Accuracy of leopard : 12 %
# Accuracy of  lion : 27 %
# Accuracy of lizard :  8 %
# Accuracy of lobster : 12 %
# Accuracy of   man : 18 %
# Accuracy of maple_tree : 42 %
# Accuracy of motorcycle : 39 %
# Accuracy of mountain : 27 %
# Accuracy of mouse :  2 %
# Accuracy of mushroom : 23 %
# Accuracy of oak_tree : 63 %
# Accuracy of orange : 57 %
# Accuracy of orchid : 37 %
# Accuracy of otter :  2 %
# Accuracy of palm_tree : 34 %
# Accuracy of  pear : 31 %
# Accuracy of pickup_truck : 31 %
# Accuracy of pine_tree : 13 %
# Accuracy of plain : 74 %
# Accuracy of plate : 52 %
# Accuracy of poppy : 45 %
# Accuracy of porcupine : 31 %
# Accuracy of possum :  8 %
# Accuracy of rabbit :  2 %
# Accuracy of raccoon :  2 %
# Accuracy of   ray : 27 %
# Accuracy of  road : 65 %
# Accuracy of rocket : 41 %
# Accuracy of  rose : 33 %
# Accuracy of   sea : 42 %
# Accuracy of  seal :  2 %
# Accuracy of shark : 27 %
# Accuracy of shrew : 14 %
# Accuracy of skunk : 44 %
# Accuracy of skyscraper : 53 %
# Accuracy of snail :  4 %
# Accuracy of snake : 10 %
# Accuracy of spider :  6 %
# Accuracy of squirrel :  1 %
# Accuracy of streetcar : 14 %
# Accuracy of sunflower : 60 %
# Accuracy of sweet_pepper : 27 %
# Accuracy of table : 10 %
# Accuracy of  tank : 50 %
# Accuracy of telephone : 32 %
# Accuracy of television : 36 %
# Accuracy of tiger :  3 %
# Accuracy of tractor : 25 %
# Accuracy of train : 10 %
# Accuracy of trout : 37 %
# Accuracy of tulip : 15 %
# Accuracy of turtle : 11 %
# Accuracy of wardrobe : 60 %
# Accuracy of whale : 40 %
# Accuracy of willow_tree : 21 %
# Accuracy of  wolf : 23 %
# Accuracy of woman : 12 %
# Accuracy of  worm : 23 %
# Accuracy of apple : 58 %
# Accuracy of aquarium_fish : 40 %
# Accuracy of  baby : 17 %
# Accuracy of  bear : 17 %
# Accuracy of beaver :  7 %
# Accuracy of   bed : 31 %
# Accuracy of   bee : 22 %
# Accuracy of beetle : 28 %
# Accuracy of bicycle : 41 %
# Accuracy of bottle : 41 %
# Accuracy of  bowl : 12 %
# Accuracy of   boy : 11 %
# Accuracy of bridge : 31 %
# Accuracy of   bus : 26 %
# Accuracy of butterfly : 22 %
# Accuracy of camel : 22 %
# Accuracy of   can : 25 %
# Accuracy of castle : 43 %
# Accuracy of caterpillar : 25 %
# Accuracy of cattle : 21 %
# Accuracy of chair : 60 %
# Accuracy of chimpanzee : 47 %
# Accuracy of clock : 20 %
# Accuracy of cloud : 50 %
# Accuracy of cockroach : 67 %
# Accuracy of couch : 22 %
# Accuracy of   cra : 15 %
# Accuracy of crocodile : 21 %
# Accuracy of   cup : 44 %
# Accuracy of dinosaur : 30 %
# Accuracy of dolphin : 36 %
# Accuracy of elephant : 32 %
# Accuracy of flatfish : 24 %
# Accuracy of forest : 23 %
# Accuracy of   fox : 17 %
# Accuracy of  girl : 14 %
# Accuracy of hamster : 23 %
# Accuracy of house : 22 %
# Accuracy of kangaroo : 19 %
# Accuracy of keyboard : 40 %
# Accuracy of  lamp : 25 %
# Accuracy of lawn_mower : 51 %
# Accuracy of leopard : 14 %
# Accuracy of  lion : 31 %
# Accuracy of lizard : 13 %
# Accuracy of lobster :  7 %
# Accuracy of   man : 19 %
# Accuracy of maple_tree : 37 %
# Accuracy of motorcycle : 51 %
# Accuracy of mountain : 41 %
# Accuracy of mouse :  8 %
# Accuracy of mushroom : 24 %
# Accuracy of oak_tree : 58 %
# Accuracy of orange : 53 %
# Accuracy of orchid : 35 %
# Accuracy of otter :  2 %
# Accuracy of palm_tree : 45 %
# Accuracy of  pear : 26 %
# Accuracy of pickup_truck : 41 %
# Accuracy of pine_tree : 19 %
# Accuracy of plain : 69 %
# Accuracy of plate : 34 %
# Accuracy of poppy : 41 %
# Accuracy of porcupine : 29 %
# Accuracy of possum :  7 %
# Accuracy of rabbit : 11 %
# Accuracy of raccoon :  9 %
# Accuracy of   ray : 21 %
# Accuracy of  road : 68 %
# Accuracy of rocket : 44 %
# Accuracy of  rose : 37 %
# Accuracy of   sea : 50 %
# Accuracy of  seal :  4 %
# Accuracy of shark : 33 %
# Accuracy of shrew : 13 %
# Accuracy of skunk : 47 %
# Accuracy of skyscraper : 56 %
# Accuracy of snail : 17 %
# Accuracy of snake :  7 %
# Accuracy of spider : 17 %
# Accuracy of squirrel :  2 %
# Accuracy of streetcar : 21 %
# Accuracy of sunflower : 58 %
# Accuracy of sweet_pepper : 17 %
# Accuracy of table : 17 %
# Accuracy of  tank : 37 %
# Accuracy of telephone : 34 %
# Accuracy of television : 31 %
# Accuracy of tiger : 17 %
# Accuracy of tractor : 34 %
# Accuracy of train : 20 %
# Accuracy of trout : 37 %
# Accuracy of tulip : 13 %
# Accuracy of turtle : 11 %
# Accuracy of wardrobe : 58 %
# Accuracy of whale : 49 %
# Accuracy of willow_tree : 25 %
# Accuracy of  wolf : 29 %
# Accuracy of woman :  9 %
# Accuracy of  worm : 14 %
# ([56.0,
#   44.0,
#   18.0,
#   14.0,
#   3.0,
#   29.0,
#   21.0,
#   28.0,
#   28.0,
#   38.0,
#   15.0,
#   19.0,
#   21.0,
#   18.0,
#   12.0,
#   13.0,
#   21.0,
#   47.0,
#   21.0,
#   20.0,
#   62.0,
#   47.0,
#   18.0,
#   51.0,
#   55.0,
#   13.0,
#   7.0,
#   12.0,
#   48.0,
#   22.0,
#   30.0,
#   19.0,
#   19.0,
#   33.0,
#   23.0,
#   10.0,
#   31.0,
#   20.0,
#   13.0,
#   25.0,
#   29.0,
#   53.0,
#   12.0,
#   27.0,
#   8.0,
#   12.0,
#   18.0,
#   42.0,
#   39.0,
#   27.0,
#   2.0,
#   23.0,
#   63.0,
#   57.0,
#   37.0,
#   2.0,
#   34.0,
#   31.0,
#   31.0,
#   13.0,
#   74.0,
#   52.0,
#   45.0,
#   31.0,
#   8.0,
#   2.0,
#   2.0,
#   27.0,
#   65.0,
#   41.0,
#   33.0,
#   42.0,
#   2.0,
#   27.0,
#   14.0,
#   44.0,
#   53.0,
#   4.0,
#   10.0,
#   6.0,
#   1.0,
#   14.0,
#   60.0,
#   27.0,
#   10.0,
#   50.0,
#   32.0,
#   36.0,
#   3.0,
#   25.0,
#   10.0,
#   37.0,
#   15.0,
#   11.0,
#   60.0,
#   40.0,
#   21.0,
#   23.0,
#   12.0,
#   23.0],
#  [58.0,
#   40.0,
#   17.0,
#   17.0,
#   7.0,
#   31.0,
#   22.0,
#   28.0,
#   41.0,
#   41.0,
#   12.0,
#   11.0,
#   31.0,
#   26.0,
#   22.0,
#   22.0,
#   25.0,
#   43.0,
#   25.0,
#   21.0,
#   60.0,
#   47.0,
#   20.0,
#   50.0,
#   67.0,
#   22.0,
#   15.0,
#   21.0,
#   44.0,
#   30.0,
#   36.0,
#   32.0,
#   24.0,
#   23.0,
#   17.0,
#   14.0,
#   23.0,
#   22.0,
#   19.0,
#   40.0,
#   25.0,
#   51.0,
#   14.0,
#   31.0,
#   13.0,
#   7.0,
#   19.0,
#   37.0,
#   51.0,
#   41.0,
#   8.0,
#   24.0,
#   58.0,
#   53.0,
#   35.0,
#   2.0,
#   45.0,
#   26.0,
#   41.0,
#   19.0,
#   69.0,
#   34.0,
#   41.0,
#   29.0,
#   7.0,
#   11.0,
#   9.0,
#   21.0,
#   68.0,
#   44.0,
#   37.0,
#   50.0,
#   4.0,
#   33.0,
#   13.0,
#   47.0,
#   56.0,
#   17.0,
#   7.0,
#   17.0,
#   2.0,
#   21.0,
#   58.0,
#   17.0,
#   17.0,
#   37.0,
#   34.0,
#   31.0,
#   17.0,
#   34.0,
#   20.0,
#   37.0,
#   13.0,
#   11.0,
#   58.0,
#   49.0,
#   25.0,
#   29.0,
#   9.0,
#   14.0])

# %% [markdown]
# ## **Section 2:  Finetuning the ConvNet**
# ### 2.1 STL-10 DATASET
# > The above networks are trained on CIFAR-100, which
# contains the images of 100 different object categories, each of which has $32\times32 \times3$ dimensions.
# The dataset we use throughout this section is a subset of [STL-10](https://cs.stanford.edu/~acoates/stl10/)
# with higher resolution and different object classes. So, there is a discrepancy between the previous dataset (CIFAR-100) and the new dataset (STL-10). One solution would be to train the whole network from scratch. However, the number of parameters is too large to be trained properly with such few images. Another way is to use the pre-trained network (on CIFAR-100) and then finetune the network on the new dataset (STL-10) (*e.g.*, use the same architectures in all layers except the output layer, as the number of output classes changes (from 100 to 5)).

# %%
# !pip install imageio
# Out:
# Requirement already satisfied: imageio in /Users/joanvelja/anaconda3/envs/cv1_torch/lib/python3.11/site-packages (2.31.5)
# Requirement already satisfied: numpy in /Users/joanvelja/anaconda3/envs/cv1_torch/lib/python3.11/site-packages (from imageio) (1.26.0)
# Requirement already satisfied: pillow>=8.3.2 in /Users/joanvelja/anaconda3/envs/cv1_torch/lib/python3.11/site-packages (from imageio) (10.0.1)

# %%
# Use the following code if necessary
# referenced code: https://cs.stanford.edu/~acoates/stl10/

from __future__ import print_function

import sys
import os, sys, tarfile, errno
import numpy as np
import matplotlib.pyplot as plt

if sys.version_info >= (3, 0, 0):
    import urllib.request as urllib
else:
    import urllib

try:
    from imageio import imsave
except:
    from scipy.misc import imsave

print(sys.version_info)

# image shape
HEIGHT = 96
WIDTH = 96
DEPTH = 3

# size of a single image in bytes
SIZE = HEIGHT * WIDTH * DEPTH

# path to the directory with the data
DATA_DIR = './data'

# url of the binary data
DATA_URL = 'http://ai.stanford.edu/~acoates/stl10/stl10_binary.tar.gz'

# path to the binary train file with image data
DATA_PATH = './data/stl10_binary/train_X.bin'

# path to the binary train file with labels
LABEL_PATH = './data/stl10_binary/train_y.bin'

def read_labels(path_to_labels):
    """
    :param path_to_labels: path to the binary file containing labels from the STL-10 dataset
    :return: an array containing the labels
    """
    with open(path_to_labels, 'rb') as f:
        labels = np.fromfile(f, dtype=np.uint8)
        return labels


def read_all_images(path_to_data):
    """
    :param path_to_data: the file containing the binary images from the STL-10 dataset
    :return: an array containing all the images
    """

    with open(path_to_data, 'rb') as f:
        # read whole file in uint8 chunks
        everything = np.fromfile(f, dtype=np.uint8)

        # We force the data into 3x96x96 chunks, since the
        # images are stored in "column-major order", meaning
        # that "the first 96*96 values are the red channel,
        # the next 96*96 are green, and the last are blue."
        # The -1 is since the size of the pictures depends
        # on the input file, and this way numpy determines
        # the size on its own.

        images = np.reshape(everything, (-1, 3, 96, 96))

        # Now transpose the images into a standard image format
        # readable by, for example, matplotlib.imshow
        # You might want to comment this line or reverse the shuffle
        # if you will use a learning algorithm like CNN, since they like
        # their channels separated.
        images = np.transpose(images, (0, 3, 2, 1))
        return images


def read_single_image(image_file):
    """
    CAREFUL! - this method uses a file as input instead of the path - so the
    position of the reader will be remembered outside of context of this method.
    :param image_file: the open file containing the images
    :return: a single image
    """
    # read a single image, count determines the number of uint8's to read
    image = np.fromfile(image_file, dtype=np.uint8, count=SIZE)
    # force into image matrix
    image = np.reshape(image, (3, 96, 96))
    # transpose to standard format
    # You might want to comment this line or reverse the shuffle
    # if you will use a learning algorithm like CNN, since they like
    # their channels separated.
    image = np.transpose(image, (2, 1, 0))
    return image


def plot_image(image):
    """
    :param image: the image to be plotted in a 3-D matrix format
    :return: None
    """
    plt.imshow(image)
    plt.show()

def save_image(image, name):
    imsave("%s.png" % name, image, format="png")

def download_and_extract():
    """
    Download and extract the STL-10 dataset
    :return: None
    """
    dest_directory = DATA_DIR
    if not os.path.exists(dest_directory):
        os.makedirs(dest_directory)
    filename = DATA_URL.split('/')[-1]
    filepath = os.path.join(dest_directory, filename)
    if not os.path.exists(filepath):
        def _progress(count, block_size, total_size):
            sys.stdout.write('\rDownloading %s %.2f%%' % (filename,
                float(count * block_size) / float(total_size) * 100.0))
            sys.stdout.flush()
        filepath, _ = urllib.urlretrieve(DATA_URL, filepath, reporthook=_progress)
        print('Downloaded', filename)
        tarfile.open(filepath, 'r:gz').extractall(dest_directory)

def save_images(images, labels):
    print("Saving images to disk")
    i = 0
    for image in images:
        label = labels[i]
        directory = './img/' + str(label) + '/'
        try:
            os.makedirs(directory, exist_ok=True)
        except OSError as exc:
            if exc.errno == errno.EEXIST:
                pass
        filename = directory + str(i)
        print(filename)
        save_image(image, filename)
        i = i + 1
# Out:
# sys.version_info(major=3, minor=11, micro=5, releaselevel='final', serial=0)

# %%
# Use the following code if necessary

# download data if needed
download_and_extract()

# test to check if the image is read correctly
with open(DATA_PATH) as f:
    image = read_single_image(f)
    plot_image(image)

# test to check if the whole dataset is read correctly
images = read_all_images(DATA_PATH)
print(images.shape)

labels = read_labels(LABEL_PATH)
print(labels.shape)

# save images to disk
save_images(images, labels)

# %% [markdown]
# #### **`Q2.1 Create the STL10_Dataset (5-pts)`**
# In this Section, download STL-10 and extract 5 classes from STL-10 training dataset. The the labels of images will be defined as:
#
# `{1: 'car', 2:'deer', 3:'horse', 4:'monkey', 5:'truck'}`
#
#  Extract mentioned 5 classes of images from STL-10. Complement *`STL10_Dataset`* class and match each class with the label accordingly. __Hint__: You can use the code above to help to complement *`STL10_Dataset`* class. (5-pts)

# %%
classes_stl = {2 : 'car', 4: 'deer', 6: 'horse', 7: 'monkey', 9: 'truck'}

# %%
class STL10_Dataset(Dataset):
    def __init__(self, root='./data', train=True, transform=None):
        self.root = root
        self.transform = transform
        self.train = train

        download_and_extract()

        data_path = f'{self.root}/stl10_binary/train_X.bin' if self.train else f'{self.root}/stl10_binary/test_X.bin'
        label_path = f'{self.root}/stl10_binary/train_y.bin' if self.train else f'{self.root}/stl10_binary/test_y.bin'

        # Read all images and labels
        self.images = read_all_images(data_path)
        self.labels = read_labels(label_path)

        # Extract only the classes we are interested in
        target_classes = {3, 5, 7, 8, 10}  # car, deer, horse, monkey, truck
        indices = [(i) for i, label in enumerate(self.labels) if label in target_classes]
        
        self.images = self.images[indices]
        self.labels = self.labels[indices]

        # Transform labels to start from 0
        self.label_map = {3: 2, 5: 4, 7: 6, 8: 7, 10: 9}
        self.labels = np.array([self.label_map[label] for label in self.labels])

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, index):
        img, target = self.images[index], self.labels[index]

        # If a transform function is provided, apply it
        if self.transform:
            img = self.transform(img)

        return img, target

# %%
stl_train_dataset, stl_test_dataset = STL10_Dataset(train=True, transform=transform_train), STL10_Dataset(train=False, transform=transform_test)
stl_train_data_loader = DataLoader(stl_train_dataset, batch_size=64, shuffle=True, num_workers=0)
stl_test_data_loader = DataLoader(stl_test_dataset, batch_size=64, shuffle=False, num_workers=0)

# %%
# get some random training images
dataiter = iter(stl_train_data_loader)
images, labels = next(dataiter)

# show images
imshow(torchvision.utils.make_grid(images))

# print labels
print(' '.join('%5s' % classes_stl[labels[j]] for j in range(5)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/joanvelja/Desktop/UvA AI/Computer Vision 1/Assignments/Lab5 Final/CV1 Final Lab Pt2 (V2).ipynb Cella 78 line 9
#       <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y200sZmlsZQ%3D%3D?line=5'>6</a> imshow(torchvision.utils.make_grid(images))
#       <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y200sZmlsZQ%3D%3D?line=7'>8</a> # print labels
# ----> <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y200sZmlsZQ%3D%3D?line=8'>9</a> print(' '.join('%5s' % classes_stl[labels[j]] for j in range(5)))
#
# /Users/joanvelja/Desktop/UvA AI/Computer Vision 1/Assignments/Lab5 Final/CV1 Final Lab Pt2 (V2).ipynb Cella 78 line 9
#       <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y200sZmlsZQ%3D%3D?line=5'>6</a> imshow(torchvision.utils.make_grid(images))
#       <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y200sZmlsZQ%3D%3D?line=7'>8</a> # print labels
# ----> <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y200sZmlsZQ%3D%3D?line=8'>9</a> print(' '.join('%5s' % classes_stl[labels[j]] for j in range(5)))
#
# KeyError: tensor(4)

# %%
assert np.all(np.unique(stl_test_dataset.labels) == np.unique(stl_train_dataset.labels)), 'Train and test labels must be the same'
len(stl_train_dataset), len(stl_test_dataset)
# Out:
# (2500, 4000)

# %% [markdown]
# ### 2.2 Fine-tuning ConvNet
# You should load the pre-trained parameters and modify the output layer of pre-trained ConvNet from 100 to 5. You can either load the pre-trained parameters and then modify the output layer, or change the output layer firstly and then load the matched pre-trained parameters. The examples can be found at [link1](https://pytorch.org/tutorials/intermediate/torchvision_tutorial.html) and [link2](https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html).

# %% [markdown]
# #### **`Q2.2  Finetuning from ConvNet (10-pts)`**
# 1. Load the pre-trained parameters (pretrained on CIFAR-100) and modify the ConvNet. (5-pts)
# 2. Train the model and show the results (settings of hyperparameters, accuracy, learning curve). (5-pts)
#
# **Hint**:  Once the network is trained, it is a good practice to understand the feature space by visualization techniques. There are several techniques to visualize the feature space. [**t-sne**](https://lvdmaaten.github.io/tsne/) is a dimensionality reduction method which can help you better understand the feature learning process.

# %%
class FeatureExtractor(nn.Module):
    def __init__(self, original_model):
        super(FeatureExtractor, self).__init__()
        self.features = nn.Sequential(*list(original_model.children())[:-1]) 
        
    def forward(self, x):
        x = self.features(x)
        return x

# %%
class AdaptedConvNet2(nn.Module):
    def __init__(self, num_classes=5): 
        super(AdaptedConvNet2, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5, stride=1)
        self.act1 = nn.Tanh()
        self.pool1 = nn.AvgPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, stride=1)
        self.act2 = nn.Tanh()
        self.pool2 = nn.AvgPool2d(kernel_size=2, stride=2)

        new_dimension = 16 * 21 * 21 
        self.fc1 = nn.Linear(in_features=new_dimension, out_features=120)
        self.act4 = nn.Tanh()
        self.fc2 = nn.Linear(in_features=120, out_features=84)
        self.act5 = nn.Tanh()
        self.fc3 = nn.Linear(in_features=84, out_features=num_classes)

    def forward(self, x):
        x = self.pool1(self.act1(self.conv1(x)))
        x = self.pool2(self.act2(self.conv2(x)))
        x = x.view(-1, 16 * 21 * 21) 
        x = self.act4(self.fc1(x))
        x = self.act5(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
################################
# Load the pre-trained parameters (pretrained on CIFAR-100) and modify the ConvNet. (5-pts)
################################
pretrained = torch.load("./convnet_CIFAR100.pth")

adapt = AdaptedConvNet2(num_classes=5)
adapt_params = adapt.state_dict()

# Filter out the layers that are different
pretrained_dict = {k: v for k, v in pretrained.items() if k in adapt_params}
pretrained_dict = {k: v for k, v in pretrained.items() if k in adapt_params and adapt_params[k].shape == pretrained[k].shape}

adapt_params.update(pretrained_dict)

# Load the new state dict
adapt.load_state_dict(adapt_params)
# Out:
# <All keys matched successfully>

# %%
################################
# Train the model and show the results (settings of hyperparameters, accuracy, learning curve). (5-pts)
################################


wandb.init(
      # Set the project where this run will be logged
      project="TransferLearning", 
      # We pass a run name (otherwise it’ll be randomly assigned, like sunshine-lollypop-10)
      name=f"experiment_{1}", 
      # Track hyperparameters and run metadata
      config={
      "Learning Rate": "1CycleLR - 1e-5 to 1e-3",
      "Architecture": "AdaptedConvNet2",
      "Dataset": "CIFAR-100",
      "Epochs": 100,
      "Batch Size": 64,
      "Optimizer": "SGD with Momentum",
      "Weight Decay": 0.01,
      "Transformations": "True"
      })
train(adapt, stl_train_data_loader, print_epoch_stats=True, epochs=100, optimizer_name = "SGD", weight_decay = 0.001, lr=1e-5, clip_value=1)
wandb.finish()
# Out:
# Finishing last run (ID:ceffzsfa) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test Accuracy</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test Accuracy</td><td>66.625</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">experiment_1_test</strong> at: <a href='https://wandb.ai/1000kelvin/TransferLearning/runs/ceffzsfa' target="_blank">https://wandb.ai/1000kelvin/TransferLearning/runs/ceffzsfa</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231021_230250-ceffzsfa/logs</code>
# Successfully finished last run (ID:ceffzsfa). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011141671299992596, max=1.0…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/Users/joanvelja/Desktop/UvA AI/Computer Vision 1/Assignments/Lab5 Final/wandb/run-20231021_230540-o47vq4ti</code>
# Syncing run <strong><a href='https://wandb.ai/1000kelvin/TransferLearning/runs/o47vq4ti' target="_blank">experiment_1</a></strong> to <a href='https://wandb.ai/1000kelvin/TransferLearning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/1000kelvin/TransferLearning' target="_blank">https://wandb.ai/1000kelvin/TransferLearning</a>
#  View run at <a href='https://wandb.ai/1000kelvin/TransferLearning/runs/o47vq4ti' target="_blank">https://wandb.ai/1000kelvin/TransferLearning/runs/o47vq4ti</a>
# Training on mps
# Using CyclicLR
# Epoch 1 Summary: Loss: 0.627, Accuracy: 11.52%, lr: [4.263387417375404e-05]
# Epoch 2 Summary: Loss: 0.515, Accuracy: 26.84%, lr: [5.050659130683647e-05]
# Epoch 3 Summary: Loss: 0.433, Accuracy: 31.28%, lr: [6.353175245618831e-05]
# Epoch 4 Summary: Loss: 0.368, Accuracy: 32.24%, lr: [8.156641330697527e-05]
# Epoch 5 Summary: Loss: 0.334, Accuracy: 32.64%, lr: [0.00010441265291150027]
# Epoch 6 Summary: Loss: 0.289, Accuracy: 32.88%, lr: [0.00013181974576783944]
# Epoch 7 Summary: Loss: 0.266, Accuracy: 33.44%, lr: [0.00016348691340077582]
# Epoch 8 Summary: Loss: 0.229, Accuracy: 33.84%, lr: [0.00019906662524787498]
# Epoch 9 Summary: Loss: 0.207, Accuracy: 34.24%, lr: [0.0002381684126252048]
# Epoch 10 Summary: Loss: 0.183, Accuracy: 34.60%, lr: [0.0002803631539164287]
# Epoch 11 Summary: Loss: 0.177, Accuracy: 35.40%, lr: [0.00032518778395756694]
# Epoch 12 Summary: Loss: 0.154, Accuracy: 35.60%, lr: [0.0003721503759343966]
# Epoch 13 Summary: Loss: 0.133, Accuracy: 36.20%, lr: [0.00042073554002133287]
# Epoch 14 Summary: Loss: 0.124, Accuracy: 36.24%, lr: [0.0004704100795145588]
# Epoch 15 Summary: Loss: 0.117, Accuracy: 36.28%, lr: [0.000520628842386306]
# Epoch 16 Summary: Loss: 0.110, Accuracy: 36.52%, lr: [0.0005708407040425505]
# Epoch 17 Summary: Loss: 0.101, Accuracy: 37.12%, lr: [0.0006204946156264901]
# Epoch 18 Summary: Loss: 0.095, Accuracy: 37.08%, lr: [0.0006690456514908466]
# Epoch 19 Summary: Loss: 0.083, Accuracy: 37.56%, lr: [0.0007159609894711529]
# Epoch 20 Summary: Loss: 0.081, Accuracy: 37.84%, lr: [0.0007607257583296615]
# Epoch 21 Summary: Loss: 0.074, Accuracy: 37.80%, lr: [0.0008028486881972461]
# Epoch 22 Summary: Loss: 0.070, Accuracy: 38.16%, lr: [0.0008418675020026516]
# Epoch 23 Summary: Loss: 0.070, Accuracy: 38.12%, lr: [0.0008773539887209923]
# Epoch 24 Summary: Loss: 0.067, Accuracy: 38.00%, lr: [0.0009089187027652489]
# Epoch 25 Summary: Loss: 0.060, Accuracy: 38.32%, lr: [0.0009362152379474081]
# Epoch 26 Summary: Loss: 0.059, Accuracy: 38.44%, lr: [0.000958944029104765]
# Epoch 27 Summary: Loss: 0.057, Accuracy: 38.24%, lr: [0.0009768556396705277]
# Epoch 28 Summary: Loss: 0.058, Accuracy: 38.36%, lr: [0.000989753499109365]
# Epoch 29 Summary: Loss: 0.049, Accuracy: 38.68%, lr: [0.0009974960601759743]
# Epoch 30 Summary: Loss: 0.052, Accuracy: 38.20%, lr: [0.0009999996852817637]
# Epoch 31 Summary: Loss: 0.047, Accuracy: 38.60%, lr: [0.0009994710518781754]
# Epoch 96 Summary: Loss: 0.016, Accuracy: 39.60%, lr: [7.939313458404149e-06]
# Epoch 97 Summary: Loss: 0.013, Accuracy: 39.76%, lr: [4.454108516507369e-06]
# Epoch 98 Summary: Loss: 0.014, Accuracy: 39.72%, lr: [1.966871079241971e-06]
# Epoch 99 Summary: Loss: 0.013, Accuracy: 39.76%, lr: [4.826101117985559e-07]
# Epoch 100 Summary: Loss: 0.013, Accuracy: 39.84%, lr: [4.314718236197908e-09]
# Finished Training
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>Learning Rate</td><td>▁▁▂▂▃▄▅▆▇▇███████▇▇▇▇▆▆▅▅▅▄▄▃▃▃▂▂▂▂▁▁▁▁▁</td></tr><tr><td>Training Accuracy</td><td>▁▆▆▇▇▇▇▇▇███████████████████████████████</td></tr><tr><td>Training Loss</td><td>█▆▄▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Training Loss / Step</td><td>▆▅▅▁▃▂▃▁▂▂▂▂▁▂▁▁▂▁▁▂▁▁▁▂▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Epoch</td><td>100</td></tr><tr><td>Learning Rate</td><td>0.0</td></tr><tr><td>Training Accuracy</td><td>39.84</td></tr><tr><td>Training Loss</td><td>0.01304</td></tr><tr><td>Training Loss / Step</td><td>0.01868</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">experiment_1</strong> at: <a href='https://wandb.ai/1000kelvin/TransferLearning/runs/o47vq4ti' target="_blank">https://wandb.ai/1000kelvin/TransferLearning/runs/o47vq4ti</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231021_230540-o47vq4ti/logs</code>

# %%
from sklearn.manifold import TSNE
import numpy as np

# Assume you have a DataLoader 'data_loader' for your test/validation dataset
feature_list = []
label_list = []

model = FeatureExtractor(adapt)  # Replace LeNet5() with your own model if needed
model.load_state_dict(torch.load("lenet5_CIFAR100.pth"))
model.eval()

with torch.no_grad():
    for data, labels in data_loader:
        features = model(data)
        features = features.view(features.size(0), -1)  # Flatten features
        feature_list.append(features)
        label_list.append(labels)

# Concatenate all the features and labels into one tensor
all_features = torch.cat(feature_list)
all_labels = torch.cat(label_list)

# Convert to NumPy array before applying t-SNE
all_features = all_features.numpy()
all_labels = all_labels.numpy()

# Apply t-SNE
tsne = TSNE(n_components=2)
embedded_features = tsne.fit_transform(all_features)

# %%
wandb.init(
      # Set the project where this run will be logged
      project="TransferLearning", 
      # We pass a run name (otherwise it’ll be randomly assigned, like sunshine-lollypop-10)
      name=f"experiment_{1}_test", 
      # Track hyperparameters and run metadata
      config={
      "Learning Rate": "1CycleLR - 1e-5 to 1e-3", 
      "Architecture": "AdaptedConvNet2",
      "Dataset": "CIFAR-100",
      "Epochs": 1,
      "Batch Size": 64,
      "Optimizer": "SGD with Momentum",
      "Weight Decay": 0.01,
      "Transformations": "True",
      "Test": "True"
      })
      
valid(adapt, stl_test_data_loader)
wandb.log({"Test Accuracy": valid(adapt, stl_test_data_loader)})

class_correct, class_total = valid_class(adapt, stl_test_data_loader, {2, 4, 6, 7, 9})

for i in range(5):
        print('Accuracy of %5s : %2d %%' % (
            classes[i], 100 * class_correct[i] / class_total[i]))
        wandb.log({"Test Accuracy / Class": 100 * class_correct[i] / class_total[i]})

wandb.finish()
# Out:
# Finishing last run (ID:tqh7qt7i) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test Accuracy</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test Accuracy</td><td>36.825</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">experiment_1_test</strong> at: <a href='https://wandb.ai/1000kelvin/TransferLearning/runs/tqh7qt7i' target="_blank">https://wandb.ai/1000kelvin/TransferLearning/runs/tqh7qt7i</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231021_230919-tqh7qt7i/logs</code>
# Successfully finished last run (ID:tqh7qt7i). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011156633800015293, max=1.0…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/Users/joanvelja/Desktop/UvA AI/Computer Vision 1/Assignments/Lab5 Final/wandb/run-20231021_231005-xx4tniug</code>
# Syncing run <strong><a href='https://wandb.ai/1000kelvin/TransferLearning/runs/xx4tniug' target="_blank">experiment_1_test</a></strong> to <a href='https://wandb.ai/1000kelvin/TransferLearning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/1000kelvin/TransferLearning' target="_blank">https://wandb.ai/1000kelvin/TransferLearning</a>
#  View run at <a href='https://wandb.ai/1000kelvin/TransferLearning/runs/xx4tniug' target="_blank">https://wandb.ai/1000kelvin/TransferLearning/runs/xx4tniug</a>
# Accuracy of the network on the 10000 test images: 36 %
# Accuracy of the network on the 10000 test images: 36 %
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/joanvelja/Desktop/UvA AI/Computer Vision 1/Assignments/Lab5 Final/CV1 Final Lab Pt2 (V2).ipynb Cella 81 line 2
#      <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y161sZmlsZQ%3D%3D?line=18'>19</a> valid(adapt, stl_test_data_loader)
#      <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y161sZmlsZQ%3D%3D?line=19'>20</a> wandb.log({"Test Accuracy": valid(adapt, stl_test_data_loader)})
# ---> <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y161sZmlsZQ%3D%3D?line=21'>22</a> class_correct, class_total = valid_class(adapt, stl_test_data_loader, {2, 4, 6, 7, 9})
#      <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y161sZmlsZQ%3D%3D?line=23'>24</a> for i in range(5):
#      <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y161sZmlsZQ%3D%3D?line=24'>25</a>         print('Accuracy of %5s : %2d %%' % (
#      <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y161sZmlsZQ%3D%3D?line=25'>26</a>             classes[i], 100 * class_correct[i] / class_total[i]))
#
# /Users/joanvelja/Desktop/UvA AI/Computer Vision 1/Assignments/Lab5 Final/CV1 Final Lab Pt2 (V2).ipynb Cella 81 line 1
#      <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y161sZmlsZQ%3D%3D?line=12'>13</a>         for i in range(len(labels)):
#      <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y161sZmlsZQ%3D%3D?line=13'>14</a>             label = labels[i]
# ---> <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y161sZmlsZQ%3D%3D?line=14'>15</a>             class_correct[label] += c[i].item()
#      <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y161sZmlsZQ%3D%3D?line=15'>16</a>             class_total[label] += 1
#      <a href='vscode-notebook-cell:/Users/joanvelja/Desktop/UvA%20AI/Computer%20Vision%201/Assignments/Lab5%20Final/CV1%20Final%20Lab%20Pt2%20%28V2%29.ipynb#Y161sZmlsZQ%3D%3D?line=17'>18</a> for i in range(len(classes)):
#
# IndexError: list index out of range

# %%
len(class_correct)
# Out:
# 100

# %% [markdown]
# #  **3. Bonus (optional)**
# Play with your code and try to get a higher accuracy on the test dataset (5 class from STL-10), as high as you can. The teams with the highest accuracy will get extra points, that will go on top of their average lab grade (weighed sum of all lab assignments) (your final grade can not exceed 10):
#
# **1st place:** *5%*
#
# **2nd and 3rd place:** *4%*
#
# **4th and 5th place:** *3%*
#
# **6th and 7th place:** *2%*
#
# **8th-10th place:** *1%*.
#
# You can adjust the hyperparameters and changing structures. Your strategies should be described and explained in your report.
#
# **Note:** Please do not use external well-defined networks and please do not add more than 3 additional (beyond the original network) convolutional layers.
#
# **Note:** The only data you can use is from CIFAR-100 and SLT-10.
#
# **Hints**:
# *   Data augmentation
# *   Grid Search
# *   Freezing early layers
# *   Modifying Architecture
# *   Modifying hyperparameters, *etc*.
# *   [Other advice](https://cs231n.github.io/transfer-learning/)

# %%
################################
# Todo: finish the code
################################

# %% [markdown]
#  # Individual Contribution Report *(Mandatory)*
#
# Because we want each student to contribute fairly to the submitted work, we ask you to fill out the textcells below. Write down your contribution to each of the assignment components in percentages. Naturally, percentages for one particular component should add up to 100% (e.g. 30% - 30% - 40%). No further explanation has to be given.

# %% [markdown]
# Name:
#
# Contribution on research: \
# Contribution on programming: \
# Contribution on writing:

# %% [markdown]
# Name:
#
# Contribution on research: \
# Contribution on programming: \
# Contribution on writing:

# %% [markdown]
# Name:
#
# Contribution on research: \
# Contribution on programming: \
# Contribution on writing:

# %% [markdown]
# Name:
#
# Contribution on research: \
# Contribution on programming: \
# Contribution on writing:

# %% [markdown]
#  # -End of Notebook-
